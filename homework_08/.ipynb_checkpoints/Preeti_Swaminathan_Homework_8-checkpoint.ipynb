# %% [markdown]
# <font face="verdana">
# #########################################################################################################################<br>
#
# # Homework 5<br>
#
# #########################################################################################################################<br>
#
# 1.	Compile a list of static links (permalinks) to individual user movie reviews from one particular website. This will be your working dataset for this assignment, as well as for assignments 7 and 8, which together will make up your semester project.
# a.	It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links. Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
# b.	Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
# c.	Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
# d.	Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.
# <br>
# <br>
# 2.	Extract noun phrase (NP) chunks from your reviews using the following procedure:
# a.	In Python, use BeautifulSoup to grab the main review text from each link.
# b.	Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.
# c.	You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.
# <br>
# <br>
# 3.	Output all the chunks in a single list for each review, and submit that output for this assignment. Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews, how many you collected, and by what means).

# %%
# Importing NLTK library and all the books
import nltk
#nltk.download()
import os
#import readline
import numpy as np
import pandas as pd
#import nltk

from nltk.corpus import PlaintextCorpusReader
from nltk.tokenize import word_tokenize, sent_tokenize
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
#import tabulate
import urllib.request

# %%
import imdb
from bs4 import BeautifulSoup
import requests
import re
import json

my_movies = ["sybil","Shutter Island","split"]
BASE_URL = "https://www.imdb.com"

# %%
tbl_imdb  = pd.DataFrame(columns = [
    'Movie_Name',
    'Review_Title',
    'Review_Desc',
    'Review_Rating',
    'Review_url'])

i_index=[]
i_index = 0

# %%
Review_Desc_all = ""
for movie_name in my_movies:
    ia = imdb.IMDb()
    results = ia.search_movie(movie_name)
    mv = results[0] #First result
    url = ia.get_imdbURL(mv) #URL for first result
    user_review_url = url+'reviews/'
    response = requests.get(user_review_url)
    soup = BeautifulSoup(response.text, 'lxml')
    try:
        #print(soup)
        reviews = soup.select('a.title')
        #print("reviews ",len(reviews))

        links = [a.attrs.get('href') for a in soup.select('a.title')]
        #print(links)

       # tbl_imdb = []

        # Store each item into dictionary (data), then put those into a list (imdb)
        for index in range(0, len(reviews)):
            # Seperate movie into: 'place', 'title', 'year'
            review_title = reviews[index].get_text()
            review_desc=""
            review_rating=""
            
            #print(r_soup)
            try:
                review_url = BASE_URL+ links[index]
                r_response = requests.get(review_url)
                r_soup = BeautifulSoup(r_response.text, 'lxml')
                
                data = json.loads(r_soup.find('script', type='application/ld+json').text)
                review_desc = data['reviewBody']
                review_rating = data['reviewRating']['ratingValue']
            except:
                pass
            
            raw_data = {'Movie_Name':movie_name,
                    'Review_Title':review_title,
                    'Review_Desc':review_desc,
                    'Review_Rating':review_rating,
                    'Review_url': links[index]}
            df_tbl = pd.DataFrame(raw_data,
            columns = [
                        'Movie_Name',
                        'Review_Title',
                        'Review_Desc',
                        'Review_Rating',
                        'Review_url'], index = [i_index + 1])
            tbl_imdb = tbl_imdb.append(df_tbl)
            Review_Desc_all = review_desc + Review_Desc_all
    except:
        print("Error ")

# %%
#a:
tbl_imdb['Review_Title'] = tbl_imdb['Review_Title'].str.replace('\n','')  
tbl_imdb.reset_index(drop=True, inplace=True)
tbl_imdb
# Out:
#         Movie_Name                                       Review_Title  \
# 0            sybil   Vivid, unsettling true story given enormous s...
# 1            sybil   More than 20 years later, I still remember th...
# 2            sybil       Shoe-hooks, white coats and the Big Chair...
# 3            sybil                                    Excellent Movie
# 4            sybil             A fascinating movie detailing Behavior
# 5            sybil     I can't emphasize how underrated this film is!
# 6            sybil               A Modern Masterpiece of movie making
# 7            sybil                                    Endearing Sybil
# 8            sybil   Split personality as a metaphor for what we m...
# 9            sybil                    Jessamine Milner, the "Grandma"
# 10           sybil         My God ! What did that monster do to you!?
# 11           sybil   Sybil DVD was both informative and disappointing
# 12           sybil                   Get this MOVIE on DVD, PLEASE!!!
# 13           sybil                  Deeply haunting movie.Amazing....
# 14           sybil   One of the greatest psychological dramas ever...
# 15           sybil                             A Triumph In Every Way
# 16           sybil                                        Great Movie
# 17           sybil   Very good movie!!!!!!! I would watch again an...
# 18           sybil   If you liked this film you must read Flora Rh...
# 19           sybil   I count this movie to be in an elite group of...
# 20           sybil                                        Still fresh
# 21           sybil                                              Sybil
# 22           sybil   An excellent movie, but it is too hard to fin...
# 23           sybil                            This Movie is Damn Good
# 24           sybil                          Definitely worth the buy!
# 25  Shutter Island                               Movie of the decade.
# 26  Shutter Island                    No one likes to be messed with.
# 27  Shutter Island   All it Takes is One Line of Dialogue to Make ...
# 28  Shutter Island                  The movie is perfect psycho drama
# 29  Shutter Island   Don't be side tracked by the obvious twist......
# ..             ...                                                ...
# 45  Shutter Island              Scorsese Lays a Very Large Rotten Egg
# 46  Shutter Island                               The Good and The Bad
# 47  Shutter Island                                   A Horrible Movie
# 48  Shutter Island                                 Completely idiotic
# 49  Shutter Island                             Boring and pretentious
# 50           split                     James McAvoy Carries This Film
# 51           split              Great movie! James McAvoy is awesome.
# 52           split   It maybe gets a bit too fantastical, but it's...
# 53           split                                Great story telling
# 54           split                                 Shyamalan Is Back!
# 55           split                               Love that he's back!
# 56           split                                 they didn't get it
# 57           split          I don't understand the hate for this film
# 58           split   A great suspense story, with a standout perfo...
# 59           split   And I Thought M. Night Shyamalan Was Loosing ...
# 60           split              Don't believe the One Star reviews...
# 61           split                               Not Perfect But Good
# 62           split                                          Rating: A
# 63           split   Split not only has Shyamalan back on the sadd...
# 64           split        The movie that got me interested into film!
# 65           split   Superb Acting by James McAvoy, but don't hold...
# 66           split                                    Multiple Scares
# 67           split       I always look forward on watching this movie
# 68           split               A Dude With TOO Much Personality....
# 69           split   A twisty, tense thriller that doubles as a su...
# 70           split   It Took Him Over a Decade but Shyamalan Final...
# 71           split      Terrible movie NOTE: **May Contain Spoilers**
# 72           split                                  What A Stinker!!!
# 73           split                                   What was that???
# 74           split   Don't waste your money ...it's time to stop s...
#
#                                           Review_Desc Review_Rating  \
# 0   How does one survive, much less overcome, long...            10
# 1   I was only 10 when I saw this on TV but still ...            10
# 2
# 3   This is one of the most impressive movies I've...            10
# 4   I saw this film a few times, and loved Sally F...
# 5   What a moving, outstandingly brilliant film st...            10
# 6   Sybil, originally aired way before my time, bu...
# 7   I loved it for the time it was made it was mad...             8
# 8   This movie isn't actually about the actual cas...            10
# 9   This was a deeply harrowing movie to watch, an...             7
# 10
# 11  The 30th anniversary DVD edition of Sybil was ...            10
# 12  We have waited long enough!  After shelling ou...            10
# 13  This film made such an impact on me when i saw...            10
# 14
# 15  Looking for light entertainment? If you are, S...            10
# 16  I have D.I.D. Out of the many portrayals and i...             8
# 17  I think this was Sally Field's best acting mov...            10
# 18  This film was produced in the 70's when psychi...            10
# 19  A wonderful movie,one of Sally Fields best! Of...             9
# 20
# 21  Hi to you all, I have also seen this movie lon...
# 22  I remember being impressed with this movie whe...            10
# 23  Seamless and distinct Field portrays her chara...             9
# 24  This movie is ridiculously good! I watched it ...            10
# 25  It is one of the best movies made by director ...            10
# 26  Shutter Island. A film that will divide the fi...            10
# 27  There is one line of dialogue, right at the en...             9
# 28  Shutter Island is the story of Teddy Daniels, ...            10
# 29
# ..                                                ...           ...
# 45
# 46
# 47
# 48
# 49
# 50  A fantastic performance by the film's star, Ja...             8
# 51  This movie will keep you watching waiting for ...             8
# 52  I was surprised to see that this movie was rel...             8
# 53  What a remarkable film! The premise of the fil...            10
# 54
# 55  M.Night Shyamalan is one of those filmmakers t...             8
# 56  firstly, i have to compare this movie to La La...            10
# 57  Let me start off by saying that I haven't real...             8
# 58  A welcome return to form for the director and ...             9
# 59  When this film made it's first debut I was hes...             7
# 60  After watching this movie, I have to say, I do...             8
# 61  I will start off by saying this film was in no...             7
# 62
# 63  What a terrific comeback for Shyamalan! Many h...             8
# 64  Wow, this is my first review on IMDB. Let's st...            10
# 65  The only reason to watch this movie is to enjo...             7
# 66
# 67
# 68
# 69  Shyamalan's inconsistencies as a director are ...             8
# 70
# 71
# 72
# 73
# 74
#
#                         Review_url
# 0   /review/rw0150243/?ref_=tt_urv
# 1   /review/rw0150241/?ref_=tt_urv
# 2   /review/rw0150244/?ref_=tt_urv
# 3   /review/rw1118556/?ref_=tt_urv
# 4   /review/rw0150250/?ref_=tt_urv
# 5   /review/rw1116047/?ref_=tt_urv
# 6   /review/rw0150251/?ref_=tt_urv
# 7   /review/rw1323374/?ref_=tt_urv
# 8   /review/rw0150242/?ref_=tt_urv
# 9   /review/rw1828264/?ref_=tt_urv
# 10  /review/rw1356560/?ref_=tt_urv
# 11  /review/rw1464500/?ref_=tt_urv
# 12  /review/rw0150248/?ref_=tt_urv
# 13  /review/rw2671492/?ref_=tt_urv
# 14  /review/rw1433902/?ref_=tt_urv
# 15  /review/rw2407862/?ref_=tt_urv
# 16  /review/rw1427871/?ref_=tt_urv
# 17  /review/rw1426231/?ref_=tt_urv
# 18  /review/rw1379665/?ref_=tt_urv
# 19  /review/rw1354149/?ref_=tt_urv
# 20  /review/rw1211909/?ref_=tt_urv
# 21  /review/rw1126016/?ref_=tt_urv
# 22  /review/rw0150247/?ref_=tt_urv
# 23  /review/rw3117555/?ref_=tt_urv
# 24  /review/rw2014722/?ref_=tt_urv
# 25  /review/rw4258956/?ref_=tt_urv
# 26  /review/rw2210881/?ref_=tt_urv
# 27  /review/rw2211895/?ref_=tt_urv
# 28  /review/rw3813630/?ref_=tt_urv
# 29  /review/rw2213941/?ref_=tt_urv
# ..                             ...
# 45  /review/rw2210461/?ref_=tt_urv
# 46  /review/rw2224023/?ref_=tt_urv
# 47  /review/rw2215866/?ref_=tt_urv
# 48  /review/rw2213038/?ref_=tt_urv
# 49  /review/rw2220104/?ref_=tt_urv
# 50  /review/rw4223017/?ref_=tt_urv
# 51  /review/rw3743908/?ref_=tt_urv
# 52  /review/rw3838371/?ref_=tt_urv
# 53  /review/rw4283002/?ref_=tt_urv
# 54  /review/rw3554367/?ref_=tt_urv
# 55  /review/rw4252271/?ref_=tt_urv
# 56  /review/rw3730905/?ref_=tt_urv
# 57  /review/rw3707061/?ref_=tt_urv
# 58  /review/rw3581984/?ref_=tt_urv
# 59  /review/rw3747516/?ref_=tt_urv
# 60  /review/rw4168847/?ref_=tt_urv
# 61  /review/rw4063469/?ref_=tt_urv
# 62  /review/rw3773992/?ref_=tt_urv
# 63  /review/rw3634262/?ref_=tt_urv
# 64  /review/rw4256627/?ref_=tt_urv
# 65  /review/rw3813985/?ref_=tt_urv
# 66  /review/rw3728793/?ref_=tt_urv
# 67  /review/rw4254330/?ref_=tt_urv
# 68  /review/rw4191775/?ref_=tt_urv
# 69  /review/rw3618263/?ref_=tt_urv
# 70  /review/rw3665316/?ref_=tt_urv
# 71  /review/rw3642628/?ref_=tt_urv
# 72  /review/rw3634611/?ref_=tt_urv
# 73  /review/rw3640428/?ref_=tt_urv
# 74  /review/rw3640309/?ref_=tt_urv
#
# [75 rows x 5 columns]

# %% [markdown]
# <font face="verdana">
# 2.	Extract noun phrase (NP) chunks from your reviews using the following procedure:<br>
# <p>a.	In Python, use BeautifulSoup to grab the main review text from each link.<br>
# <p>b.	Next run each review text through a tokenizer, and then try to cr.<br>
# <p>c.	You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.

# %%
from nltk.corpus import stopwords 
from string import punctuation
customStopWords=set(stopwords.words('english')+list(punctuation))

# %%
tbl_imdb['word_token']=""
tbl_imdb['tagged']=""
tbl_imdb['subtree']=""

# %%
#NP_grammar = "NP: {<DT>?<JJ>*<NN>}"
NP_grammar = r"""
  NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
      {<NNP>+}                # chunk sequences of proper nouns
      {<DT>?<JJ.><NN.*>+}
      {<PRP$><NNP>+<NN>}
      {<DT><NN><VBG>}
      {<CD><NN><TO><CD><NN>}
      {<JJR><IN><CD><NN>}
      {<DT><JJS><VBG><NNS>}
"""
for index, row in tbl_imdb.iterrows():
    print("Movie:",row[0],"\nReview heading:",row[1],"\nRating:",row[3])
    #a: 
    text = row[2].strip()
    if row[2].strip() != '':
        tokens = nltk.word_tokenize(text)
        #print("\ntokens ",tokens)
        tbl_imdb.ix[index,'word_token'] = tokens
        
        tagged = nltk.pos_tag(tokens)
        #print("\n tagged ",tagged)
        tbl_imdb.ix[index,'tagged'] = tagged

        entities = nltk.chunk.ne_chunk(tagged)
        #print("\n entities ",entities)
        #tbl_imdb.ix[index,'entities'] = entities
        
        cp = nltk.RegexpParser(NP_grammar)
        result = cp.parse(entities)
        #print("NP Chunk:")
        NPChunk=""
        for subtree in result.subtrees():
            if subtree.label() == 'NP': 
                print(subtree)
                NPChunk = NPChunk + str(subtree) + ""
        
        tbl_imdb.ix[index,'subtree'] = NPChunk
                
       # tbl_imdb.ix[index,'subtree'] = NPChunk
    print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n",)
# Out:
# Movie: sybil
# Review heading:  Vivid, unsettling true story given enormous stature by Joanne Woodward and Emmy-winning Sally Field.
# Rating: 10
# (NP survive/NN)
# (NP long-standing/JJ child/NN)
# (NP abuse/NN)
# (NP food/NN)
# (NP water/NN)
# (NP car/NN)
# (NP a/DT parent/NN)
# (NP works/NN)
# (NP yesterday/NN)
# (NP paper/NN)
# (NP an/DT archbishop/NN)
# (NP a/DT progressive/JJ church/NN)
# (NP the/DT strangulation/NN)
# (NP a/DT 15-year-old/JJ girl/NN)
# (NP the/DT opposite/JJ page/NN)
# (NP a/DT woman/NN)
# (NP boyfriend/NN)
# (NP a/DT metal/NN)
# (NP pipe/NN)
# (NP abuse/NN)
# (NP a/DT child/NN)
# (NP get/NN)
# (NP WHILE/NNP IT/NNP)
# (NP HAPPENING/NNP)
# (NP Somehow/NNP)
# (NP some/DT way/NN)
# (NP some/DT sort/NN)
# (NP mental/JJ toughness/NN)
# (NP defense/NN)
# (NP mechanism/NN)
# (NP the/DT agony/NN)
# (NP fear/NN)
# (NP emotional/JJ withdrawal/NN)
# (NP the/DT titular/JJ victim/NN)
# (NP incessant/JJ child/NN)
# (NP abuse/NN)
# (NP a/DT woman/NN)
# (NP order/NN)
# (NP a/DT mother/NN)
# (NP indescribable/JJ childhood/NN)
# (NP nothing/NN)
# (NP speed/NN)
# (NP inner/JJ family/NN)
# (NP a/DT mothering/NN)
# (NP Mary/NNP)
# (NP Vicky/NNP)
# (NP any/DT situation/NN)
# (NP anything/NN)
# (NP a/DT hostile/JJ argument/NN)
# (NP piano/NN)
# (NP music/NN)
# (NP street/NN)
# (NP a/DT word/NN)
# (NP performance/NN)
# (NP real/JJ name/NN)
# (NP the/DT ability/NN)
# (NP an/DT extent/NN)
# (NP a/DT flood/NN)
# (NP infantile/JJ behavior/NN)
# (NP the/DT drop/NN)
# (NP a/DT hat/NN)
# (NP a/DT compelling/NN)
# (NP all-consuming/JJ feat/NN)
# (NP improvisatory/NN)
# (NP style/NN)
# (NP particular/JJ marvel/NN)
# (NP a/DT scene/NN)
# (NP psychologist/NN)
# (NP patient/NN)
# (NP an/DT artist/NN)
# (NP nature/NN)
# (NP a/DT piano/NN)
# (NP immature/NN)
# (NP torment/NN)
# (NP paper/NN)
# (NP director/NN)
# (NP credit/NN)
# (NP a/DT safe/JJ environment/NN)
# (NP Emmy/NNP)
# (NP a/DT one-note/JJ actress/NN)
# (NP a/DT Gidget-like/JJ cuteness/NN)
# (NP an/DT ironic/JJ bit/NN)
# (NP casting/NN)
# (NP the/DT role/NN)
# (NP psychologist/NN)
# (NP Dr./NNP Cornelia/NNP)
# (NP mental/JJ disability/NN)
# (NP arduous/JJ journey/NN)
# (NP a/DT similar/JJ victim/NN)
# (NP multiple/JJ personality/NN)
# (NP disorder/NN)
# (NP dated/JJ film/NN)
# (NP Eve/NNP)
# (NP element/NN)
# (NP a/DT light/NN)
# (NP the/DT end/NN)
# (NP the/DT tunnel/NN)
# (NP unfortunate/JJ girl/NN)
# (NP an/DT unsuspecting/JJ acquaintance/NN)
# (NP a/DT tender/NN)
# (NP sympathetic/JJ chapter/NN)
# (NP turbulent/JJ life/NN)
# (NP bloodless/NN)
# (NP father/NN)
# (NP stepmother/NN)
# (NP puzzling/NN)
# (NP problem/NN)
# (NP a/DT significant/JJ scene/NN)
# (NP small-town/JJ doctor/NN)
# (NP a/DT child/NN)
# (NP examination/NN)
# (NP flashback/NN)
# (NP childhood/NN)
# (NP torment/NN)
# (NP grandmother/NN)
# (NP a/DT doting/NN)
# (NP grandma/NN)
# (NP brief/NN)
# (NP respite/NN)
# (NP chilling/JJ portrait/NN)
# (NP evil/NN)
# (NP TV/NN)
# (NP monster/NN)
# (NP a/DT mother/NN)
# (NP believability/NN)
# (NP unbalanced/JJ woman/NN)
# (NP sadistic/JJ pleasure/NN)
# (NP a/DT respected/JJ stage/NN)
# (NP actress/NN)
# (NP film/NN)
# (NP another/DT bizarre/NN)
# (NP screen/JJ role/NN)
# (NP a/DT crazy/NN)
# (NP self-abusing/JJ mental/JJ patient/NN)
# (NP menace/NN)
# (NP a/DT number/NN)
# (NP child/NN)
# (NP nature/NN)
# (NP DID/NNP)
# (NP Hopefully/NNP)
# (NP this/DT dark/NN)
# (NP TV-movie/NNP)
# (NP selling/NN)
# (NP book/NN)
# (NP childhood/NN)
# (NP blackout/NN)
# (NP Sybil/NNP)
# (NP the/DT entire/JJ sixth/NN)
# (NP grade/NN)
# (NP the/DT battle/NN)
# (NP control/NN)
# (NP the/DT subsequent/JJ unifying/NN)
# (NP process/NN)
# (NP the/DT professional/JJ vantage/NN)
# (NP point/NN)
# (NP Dr./NNP)
# (NP depth/NN)
# (NP Trust/NNP)
# (NP child/NN)
# (NP abuse/NN)
# (NP the/DT confusing/NN)
# (NP chopped-up/JJ two-hour/JJ version/NN)
# (NP tape/NN)
# (NP three-hour/JJ long/JJ drama/NN)
# (NP THIS/NNP)
# (NP version/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  More than 20 years later, I still remember this riveting and emotional movie.
# Rating: 10
# (NP TV/NN)
# (NP a/DT woman/NN)
# (NP a/DT child/NN)
# (NP mother/NN)
# (NP a/DT result/NN)
# (NP heart-breaking/NN)
# (NP the/DT psychologist/NN)
# (NP this/DT movie/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Shoe-hooks, white coats and the Big Chair...
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Excellent Movie
# Rating: 10
# (NP acting/NN)
# (NP an/DT award/NN)
# (NP Ms./NNP)
# (NP portrayal/NN)
# (NP this/DT poor/JJ girl/NN)
# (NP Sybil/NNP)
# (NP insight/NN)
# (NP the/DT part/NN)
# (NP role/NN)
# (NP the/DT psychiatrist/NN)
# (NP thru/NN)
# (NP memory/NN)
# (NP ordeal/NN)
# (NP abhorrent/NN)
# (NP upbringing/NN)
# (NP The/DT movie/NN)
# (NP thorough/JJ understanding/NN)
# (NP a/DT great/JJ movie/NN)
# (NP psychology/NN)
# (NP anyone/NN)
# (NP the/DT psychology/NN)
# (NP the/DT mind/NN)
# (NP trauma/NN)
# (NP this/DT movie/NN)
# (NP personal/JJ insight/NN)
# (NP own/JJ abusive/JJ upbringing/NN)
# (NP a/DT great/JJ film/NN)
# (NP entertainment/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  A fascinating movie detailing Behavior
# Rating:
# (NP this/DT film/NN)
# (NP performance/NN)
# (NP a/DT harrowing/NN)
# (NP child/NN)
# (NP abuse/NN)
# (NP inner/JJ child/NN)
# (NP The/DT way/NN)
# (NP Sybil/NNP)
# (NP therapy/NN)
# (NP Dr./NNP Wilbur.This/NNP)
# (NP film/NN)
# (NP childhood/NN)
# (NP rosey/NN)
# (NP bright/NN)
# (NP the/DT poor/JJ child/NN)
# (NP a/DT rope/NN)
# (NP the/DT mom/NN)
# (NP an/DT enima.We/NN)
# (NP the/DT mother/NN)
# (NP lock/NN)
# (NP a/DT dark/NN)
# (NP the/DT film/NN)
# (NP a/DT person/NN)
# (NP The/DT way/NN)
# (NP Dr./NNP)
# (NP That/DT expression/NN)
# (NP affection/NN)
# (NP the/DT poor/JJ child/NN)
# (NP this/DT film/NN)
# (NP own/JJ worth/NN)
# (NP gain/NN)
# (NP strength/NN)
# (NP character/NN)
# (NP the/DT perfect/JJ person/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  I can't emphasize how underrated this film is!
# Rating: 10
# (NP a/DT moving/NN)
# (NP brilliant/JJ film/NN)
# (NP an/DT Emmy/NN)
# (NP performance/NN)
# (NP Sybil/NNP)
# (NP Psychological/NNP)
# (NP drama/NN)
# (NP a/DT true/JJ story/NN)
# (NP a/DT 20-something/JJ supply-teacher/NN)
# (NP treatment/NN)
# (NP volatile/JJ mother/NN)
# (NP the/DT help/NN)
# (NP psychiatrist/NN)
# (NP Streep-like/NNP)
# (NP actress/NN)
# (NP this/DT generation/NN)
# (NP unaware/NN)
# (NP erratic/JJ next/JJ role/NN)
# (NP a/DT woman/NN)
# (NP portray/NN)
# (NP each/DT character/NN)
# (NP a/DT shame/NN)
# (NP Sybil/NNP)
# (NP role/NN)
# (NP patient/JJ psychiatrist/NN)
# (NP a/DT normal/JJ woman/NN)
# (NP CV/NNP)
# (NP a/DT hold/NN)
# (NP The/DT only/JJ problem/NN)
# (NP the/DT video/NN)
# (NP fact/NN)
# (NP a/DT pirate/JJ copy/NN)
# (NP the/DT end/NN)
# (NP the/DT sodding/NN)
# (NP film/NN)
# (NP the/DT end/NN)
# (NP the/DT film/NN)
# (NP enjoyment/NN)
# (NP a/DT message/NN)
# (NP the/DT message/NN)
# (NP board/NN)
# (NP hope/NN)
# (NP an/DT answer/NN)
# (NP someone/NN)
# (NP overwhelming/NN)
# (NP only/JJ question/NN)
# (NP the/DT hell/NN)
# (NP TV/NN)
# (NP sense/NN)
# (NP hour/NN)
# (NP uncut/JJ version/NN)
# (NP a/DT range/NN)
# (NP commentary/NN)
# (NP a/DT documentary/NN)
# (NP Sybil/NNP)
# (NP a/DT selection/NN)
# (NP non-English/JJ speaking/NN)
# (NP UPDATE/NN)
# (NP delight/NN)
# (NP sense/NN)
# (NP disk/NN)
# (NP uncut/JJ version/NN)
# (NP May/NNP)
# (NP 30th/JJ anniversary/NN)
# (NP calendar/NN)
# (NP Tick-tock/NN)
# (NP tick-tock/NN)
# (NP tick-tock/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  A Modern Masterpiece of movie making
# Rating:
# (NP way/NN)
# (NP time/NN)
# (NP a/DT chance/NN)
# (NP health/NN)
# (NP class/NN)
# (NP school/NN)
# (NP channel/NN)
# (NP surfing/NN)
# (NP the/DT movie/NN)
# (NP an/DT interest/NN)
# (NP class/NN)
# (NP The/DT movie/NN)
# (NP the/DT life/NN)
# (NP the/DT body/NN)
# (NP person/NN)
# (NP The/DT movie/NN)
# (NP a/DT hard/JJ subject/NN)
# (NP scene/NN)
# (NP the/DT end/NN)
# (NP the/DT movie/NN)
# (NP crazy/JJ mom/NN)
# (NP a/DT trunk/NN)
# (NP mother/NN)
# (NP through/NN)
# (NP a/DT shame/NN)
# (NP this/DT young/JJ woman/NN)
# (NP life/NN)
# (NP an/DT Emmy/NN)
# (NP compelling/NN)
# (NP complex/JJ performance/NN)
# (NP the/DT title/NN)
# (NP character/NN)
# (NP each/DT personality/NN)
# (NP talented/JJ actress/NN)
# (NP the/DT performance/NN)
# (NP any/DT part/NN)
# (NP this/DT film/NN)
# (NP Oscar/NNP)
# (NP winning/NN)
# (NP performance/NN)
# (NP a/DT woman/NN)
# (NP outstanding/JJ job/NN)
# (NP best/JJS performances/NNS)
# (NP The/DT movie/NN)
# (NP made/NN)
# (NP television/NN)
# (NP a/DT movie/NN)
# (NP hope/NN)
# (NP sadness/NN)
# (NP an/DT excellent/JJ piece/NN)
# (NP movie/NN)
# (NP making/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Endearing Sybil
# Rating: 8
# (NP the/DT time/NN)
# (NP sweet/NN)
# (NP emotion/NN)
# (NP fear/NN)
# (NP No/DT wonder/NN)
# (NP a/DT great/JJ actress/NN)
# (NP Flying/NNP Nun/NNP)
# (NP story/NN)
# (NP anyone/NN)
# (NP No/DT one/NN)
# (NP a/DT great/JJ movie/NN)
# (NP way/NN)
# (NP the/DT story/NN)
# (NP depth/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Split personality as a metaphor for what we must all do to survive intense pain
# Rating: 10
# (NP This/DT movie/NN)
# (NP the/DT actual/JJ case/NN)
# (NP selling/NN)
# (NP novel/NN)
# (NP a/DT metaphor/NN)
# (NP childhood/NN)
# (NP the/DT plight/NN)
# (NP performance/NN)
# (NP only/JJ stunning/JJ performance/NN)
# (NP underrated/JJ actress/NN)
# (NP fine/JJ writing/NN)
# (NP this/DT movie/NN)
# (NP mind/NN)
# (NP monster/NN)
# (NP the/DT green/JJ kitchen/NN)
# (NP silk/NN)
# (NP breathe/NN)
# (NP the/DT foreseeable/JJ future/NN)
# (NP great/JJ acting/JJ look/NN)
# (NP Godfather/NNP)
# (NP this/DT movie/NN)
# (NP the/DT source/NN)
# (NP material/NN)
# (NP a/DT serious/JJ kind/NN)
# (NP the/DT human/JJ condition/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Jessamine Milner, the "Grandma"
# Rating: 7
# (NP harrowing/JJ movie/NN)
# (NP A/DT small/JJ child/NN)
# (NP the/DT grip/NN)
# (NP insane/JJ mother/NN)
# (NP sadistic/JJ torture/NN)
# (NP ineffective/JJ husband/NN)
# (NP the/DT other/JJ way/NN)
# (NP abuse/NN)
# (NP a/DT small/JJ performance/NN)
# (NP this/DT movie/NN)
# (NP anything/NN)
# (NP the/DT film/NN)
# (NP the/DT part/NN)
# (NP the/DT grandmother/NN)
# (NP a/DT victim/NN)
# (NP prisoner/NN)
# (NP the/DT home/NN)
# (NP psychotic/JJ daughter/NN)
# (NP The/DT difference/NN)
# (NP the/DT extent/NN)
# (NP daughter/NN)
# (NP insanity/NN)
# (NP a/DT prisoner/NN)
# (NP own/JJ adult/NN)
# (NP child/NN)
# (NP home/NN)
# (NP abuse/NN)
# (NP grandchild/NN)
# (NP That/DT kind/NN)
# (NP helplessness/NN)
# (NP hell/NN)
# (NP son-in-law/NN)
# (NP the/DT police/NN)
# (NP any/DT time/NN)
# (NP the/DT house/NN)
# (NP anything/NN)
# (NP a/DT blind/NN)
# (NP eye/NN)
# (NP the/DT time/NN)
# (NP performance/NN)
# (NP affecting/NN)
# (NP the/DT film/NN)
# (NP the/DT film/NN)
# (NP film/NN)
# (NP a/DT mystery/NN)
# (NP few/JJ TV/NN)
# (NP nothing/NN)
# (NP a/DT mention/NN)
# (NP performance/NN)
# (NP film/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  My God ! What did that monster do to you!?
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Sybil DVD was both informative and disappointing
# Rating: 10
# (NP edition/NN)
# (NP July/NNP)
# (NP Sybil/NNP)
# (NP long/JJ time/NN)
# (NP friend/NN)
# (NP the/DT documentary/NN)
# (NP the/DT making/NN)
# (NP the/DT movie/NN)
# (NP The/DT documentary/NN)
# (NP a/DT fascinating/JJ recap/NN)
# (NP the/DT movie/NN)
# (NP the/DT documentary/NN)
# (NP name/NN)
# (NP the/DT gallery/NN)
# (NP a/DT person/NN)
# (NP a/DT fictional/JJ character/NN)
# (NP name/NN)
# (NP the/DT author/NN)
# (NP the/DT book/NN)
# (NP WAS/NNP Sybil/NNP)
# (NP life/NN)
# (NP an/DT artist/NN)
# (NP a/DT story/NN)
# (NP abuse/NN)
# (NP recovery/NN)
# (NP friend/NN)
# (NP the/DT recognition/NN)
# (NP a/DT survivor/NN)
# (NP abuse/NN)
# (NP a/DT wonderful/JJ artist/NN)
# (NP a/DT warm/NN)
# (NP kind/NN)
# (NP lady/NN)
# (NP a/DT quiet/JJ life/NN)
# (NP dignity/NN)
# (NP book/NN)
# (NP Words/NNP)
# (NP that/DT omission/NN)
# (NP Friend/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Get this MOVIE on DVD, PLEASE!!!
# Rating: 10
# (NP copy/NN)
# (NP this/DT movie/NN)
# (NP a/DT demand/NN)
# (NP this/DT film/NN)
# (NP the/DT full/JJ version/NN)
# (NP the/DT time/NN)
# (NP such/JJ popularity/NN)
# (NP E.R/NNP)
# (NP own/JJ show/NN)
# (NP this/DT film/NN)
# (NP Trust/NNP)
# (NP Please/NNP)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Deeply haunting movie.Amazing....
# Rating: 10
# (NP This/DT film/NN)
# (NP an/DT impact/NN)
# (NP i/NN)
# (NP i/NN)
# (NP release/NN)
# (NP DVD.Sally/NNP)
# (NP field/NN)
# (NP actress/NN)
# (NP a/DT little/JJ more..Her/JJ performance/NN)
# (NP this/DT day/NN)
# (NP a/DT role/NN)
# (NP the/DT mother/NN)
# (NP monster/NN)
# (NP a/DT parent/NN)
# (NP daughter/NN)
# (NP flashbacks.This/JJ movie/NN)
# (NP a/DT film/NN)
# (NP ability/NN)
# (NP a/DT terrible/JJ subject/NN)
# (NP this/DT movie/NN)
# (NP ground/NN)
# (NP breaking/NN)
# (NP the/DT time/NN)
# (NP the/DT first/JJ time/NN)
# (NP the/DT full/JJ version/NN)
# (NP this/DT film/NN)
# (NP the/DT attention.If/NN)
# (NP the/DT cut/NN)
# (NP version/NN)
# (NP pleased/JJ i/NN)
# (NP Emmy/NNP)
# (NP this/DT movie/NN)
# (NP real/JJ talent/NN)
# (NP a/DT nod.Please/NN)
# (NP watch/NN)
# (NP this/DT movie/NN)
# (NP warning/NN)
# (NP mind..It/NN)
# (NP ../NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  One of the greatest psychological dramas ever made
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  A Triumph In Every Way
# Rating: 10
# (NP light/JJ entertainment/NN)
# (NP a/DT remarkable/JJ combination/NN)
# (NP this/DT TV/NN)
# (NP Drama/NNP)
# (NP a/DT feature/NN)
# (NP film/NN)
# (NP the/DT controversial/JJ subject/JJ matter/NN)
# (NP the/DT drama/NN)
# (NP a/DT talented/JJ director/NN)
# (NP an/DT Oscar-winning/JJ production/NN)
# (NP the/DT board/NN)
# (NP central/JJ performance/NN)
# (NP sensitive/JJ direction/NN)
# (NP a/DT powerful/JJ storyline/NN)
# (NP a/DT real/JJ victim/NN)
# (NP remarkable/JJ recovery/NN)
# (NP the/DT top/JJ echelon/NN)
# (NP any/DT film/NN)
# (NP All/DT credit/NN)
# (NP the/DT company/NN)
# (NP Sybil/NNP)
# (NP This/DT reviewer/NN)
# (NP a/DT copy/NN)
# (NP permanent/JJ collection/NN)
# (NP a/DT thorough/JJ examination/NN)
# (NP complex/JJ mental/NN)
# (NP health/NN)
# (NP the/DT value/NN)
# (NP psychotherapy/NN)
# (NP a/DT form/NN)
# (NP dissociation/NN)
# (NP The/DT sufferer/NN)
# (NP refuge/NN)
# (NP a/DT number/NN)
# (NP reality/NN)
# (NP The/DT sufferer/NN)
# (NP personality/NN)
# (NP severe/JJ trauma/NN)
# (NP childhood/NN)
# (NP a/DT full/JJ recovery/NN)
# (NP a/DT remarkable/JJ feat/NN)
# (NP a/DT great/JJ deal/NN)
# (NP psychological/JJ therapy/NN)
# (NP DVD/NNP)
# (NP emotional/JJ health/NN)
# (NP the/DT past/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Great Movie
# Rating: 8
# (NP D.I.D/NNP)
# (NP the/DT real/JJ thing/NN)
# (NP DID/MPD/NNP)
# (NP helpless/NN)
# (NP none/NN)
# (NP dispatcher/NN)
# (NP a/DT therapist/NN)
# (NP a/DT social/JJ worker/NN)
# (NP a/DT job/NN)
# (NP the/DT entire/JJ personality/NN)
# (NP system/NN)
# (NP someone/NN)
# (NP the/DT personality/NN)
# (NP system/NN)
# (NP the/DT ability/NN)
# (NP act/NN)
# (NP the/DT rough/JJ stuff/NN)
# (NP the/DT way/NN)
# (NP the/DT way/NN)
# (NP the/DT way/NN)
# (NP generation/NN)
# (NP understanding/NN)
# (NP the/DT way/NN)
# (NP the/DT 30th/JJ anniversary/NN)
# (NP a/DT testament/NN)
# (NP the/DT perseverance/NN)
# (NP the/DT human/JJ condition/NN)
# (NP severe/JJ abuse/NN)
# (NP courageousness/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Very good movie!!!!!!! I would watch again and again
# Rating: 10
# (NP movie/NN)
# (NP a/DT story/NN)
# (NP the/DT psychiatrist/NN)
# (NP the/DT man/NN)
# (NP a/DT good/JJ human/JJ story/NN)
# (NP person/NN)
# (NP this/DT movie/NN)
# (NP a/DT good/JJ idea/NN)
# (NP the/DT person/NN)
# (NP the/DT picture/NN)
# (NP life/NN)
# (NP story/NN)
# (NP monster/NN)
# (NP a/DT child/NN)
# (NP anybody/NN)
# (NP a/DT child/NN)
# (NP the/DT doctor/NN)
# (NP the/DT enema/NN)
# (NP child/NN)
# (NP abuse/NN)
# (NP an/DT adult/NN)
# (NP mother/NN)
# (NP the/DT whole/JJ plot/NN)
# (NP the/DT psychiatrist/NN)
# (NP course/NN)
# (NP boyfriend/NN)
# (NP the/DT psychiatrist/NN)
# (NP some/DT investigating/NN)
# (NP the/DT crayon/NN)
# (NP the/DT box/NN)
# (NP the/DT story/NN)
# (NP peace/NN)
# (NP the/DT real/JJ Sybil/NN)
# (NP college/NN)
# (NP part/NN)
# (NP a/DT normal/JJ life/NN)
# (NP the/DT story/NN)
# (NP a/DT woman/NN)
# (NP body/NN)
# (NP this/DT movie/NN)
# (NP mental/JJ illness/NN)
# (NP illness/NN)
# (NP today/NN)
# (NP society/NN)
# (NP looney/NN)
# (NP depression/NN)
# (NP the/DT disease/NN)
# (NP something/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  If you liked this film you must read Flora Rheta Schreiber's book...
# Rating: 10
# (NP This/DT film/NN)
# (NP psychiatry/NN)
# (NP therapy/NN)
# (NP taboo/NN)
# (NP the/DT statement/NN)
# (NP father/NN)
# (NP need/NN)
# (NP medical/JJ treatment/NN)
# (NP the/DT devil/NN)
# (NP a/DT sea/NN)
# (NP a/DT hospital/NN)
# (NP society/NN)
# (NP a/DT marked/JJ example/NN)
# (NP the/DT world/NN)
# (NP the/DT real/JJ life/NN)
# (NP lead/NN)
# (NP an/DT intelligent/JJ woman/NN)
# (NP illness/NN)
# (NP month/NN)
# (NP father/NN)
# (NP tenement/NN)
# (NP Dr./NNP Cornelia/NNP)
# (NP the/DT eminent/JJ psychoanalyst/NN)
# (NP past/NN)
# (NP the/DT root/NN)
# (NP illness/NN)
# (NP scene/NN)
# (NP childhood/NN)
# (NP the/DT extent/NN)
# (NP the/DT child/NN)
# (NP mother/NN)
# (NP treatment/NN)
# (NP paranoid/JJ schizophrenia/NN)
# (NP This/DT film/NN)
# (NP truth/NN)
# (NP the/DT only/JJ agenda/NN)
# (NP the/DT patient/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  I count this movie to be in an elite group of Sally Fields three greatest performances
# Rating: 9
# (NP A/DT wonderful/JJ movie/NN)
# (NP coarse/NN)
# (NP the/DT book/NN)
# (NP the/DT book/NN)
# (NP this/DT movie/NN)
# (NP CLOSE/NNP)
# (NP an/DT excellent/JJ performance/NN)
# (NP %/NN)
# (NP agree/NN)
# (NP time/NN)
# (NP this/DT movie/NN)
# (NP important/JJ achievement/NN)
# (NP this/DT movie/NN)
# (NP conveyance/NN)
# (NP story/NN)
# (NP the/DT viewer/NN)
# (NP a/DT compassionate/NN)
# (NP relating/NN)
# (NP the/DT main/JJ character/NN)
# (NP Sybil/NNP)
# (NP child-like/JJ innocence/NN)
# (NP a/DT strength/NN)
# (NP character/NN)
# (NP unsinkable/JJ spirit/NN)
# (NP horrendous/JJ abuse/NN)
# (NP this/DT strength/NN)
# (NP spirit/NN)
# (NP mind/NN)
# (NP the/DT devastating/JJ reach/NN)
# (NP insanity/NN)
# (NP grip/NN)
# (NP mixture/NN)
# (NP child-like/JJ innocence/NN)
# (NP unsinkable/JJ strength/NN)
# (NP likable/JJ Hero/NN)
# (NP the/DT viewer/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Still fresh
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Sybil
# Rating:
# (NP this/DT movie/NN)
# (NP the/DT book/NN)
# (NP video/NN)
# (NP video/NN)
# (NP no/DT one/NN)
# (NP no/DT avail/NN)
# (NP time/NN)
# (NP pressure/NN)
# (NP much/JJ rubbish/NN)
# (NP cant/NN)
# (NP an/DT actual/JJ meaning/NN)
# (NP truth/NN)
# (NP some/DT understanding/NN)
# (NP the/DT life/NN)
# (NP way/NN)
# (NP Please/NNP)
# (NP DVD/NNP)
# (NP please/NN)
# (NP please/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  An excellent movie, but it is too hard to find a copy!
# Rating: 10
# (NP this/DT movie/NN)
# (NP TV/NN)
# (NP a/DT copy/NN)
# (NP no/DT success/NN)
# (NP Dead/NNP)
# (NP Chosen/NNP)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  This Movie is Damn Good
# Rating: 9
# (NP a/DT true/JJ story/NN)
# (NP the/DT writer/NN)
# (NP capture/NN)
# (NP the/DT harrowing/NN)
# (NP precision/NN)
# (NP intellect/NN)
# (NP the/DT aid/NN)
# (NP gore/NN)
# (NP Psychological/JJ terror/NN)
# (NP effective/JJ tool/NN)
# (NP the/DT horrifying/NN)
# (NP a/DT mass/NN)
# (NP blubbering/NN)
# (NP red/JJ water/NN)
# (NP the/DT reader/NN)
# (NP skillful/JJ writing/NN)
# (NP superb/NN)
# (NP acting/NN)
# (NP this/DT film/NN)
# (NP the/DT stereotype/NN)
# (NP T.V/NNP)
# (NP movie/NN)
# (NP A/DT work/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: sybil
# Review heading:  Definitely worth the buy!
# Rating: 10
# (NP This/DT movie/NN)
# (NP high/JJ school/NN)
# (NP class/NN)
# (NP today/NN)
# (NP a/DT buy/NN)
# (NP watch/NN)
# (NP this/DT movie/NN)
# (NP anything/NN)
# (NP personality/NN)
# (NP a/DT classic/JJ movie/NN)
# (NP the/DT time/NN)
# (NP the/DT quality/NN)
# (NP this/DT film/NN)
# (NP Anyone/NN)
# (NP psychology/NN)
# (NP this/DT movie/NN)
# (NP this/DT movie/NN)
# (NP collection/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Movie of the decade.
# Rating: 10
# (NP the/DT best/JJS movies/NNS)
# (NP director/NN)
# (NP movie/NN)
# (NP speaking/NN)
# (NP the/DT greatest/JJS films/NNS)
# (NP the/DT decade/NN)
# (NP Inception/NN)
# (NP this/DT day/NN)
# (NP cinematic/JJ experience/NN)
# (NP Inception/NNP)
# (NP a/DT little/JJ bit/NN)
# (NP a/DT masterpiece/NN)
# (NP The/DT beginning/NN)
# (NP the/DT movie/NN)
# (NP basic/JJ plot/NN)
# (NP a/DT detective/JJ story/NN)
# (NP a/DT thriller/NN)
# (NP the/DT movie/NN)
# (NP the/DT plot/NN)
# (NP complexity/NN)
# (NP The/DT way/NN)
# (NP The/DT pacing/NN)
# (NP the/DT movie/NN)
# (NP the/DT movie/NN)
# (NP the/DT major/JJ plot/NN)
# (NP the/DT final/JJ twist/NN)
# (NP plot/NN)
# (NP the/DT main/JJ character/NN)
# (NP a/DT lot/NN)
# (NP a/DT lot/NN)
# (NP the/DT final/JJ twist/NN)
# (NP the/DT story/NN)
# (NP The/DT character/NN)
# (NP the/DT character/NN)
# (NP the/DT character/NN)
# (NP another/DT excellent/JJ thing/NN)
# (NP this/DT movie/NN)
# (NP some/DT dream/NN)
# (NP a/DT filler/NN)
# (NP a/DT major/JJ indication/NN)
# (NP the/DT reveal/NN)
# (NP no/DT real/JJ meaning/NN)
# (NP the/DT end/NN)
# (NP a/DT diversion/NN)
# (NP the/DT story/NN)
# (NP the/DT main/JJ character/NN)
# (NP an/DT imprisoned/JJ character/NN)
# (NP different/JJ interpretation/NN)
# (NP all/DT set/NN)
# (NP a/DT complex/JJ story/NN)
# (NP a/DT lot/NN)
# (NP the/DT main/JJ character/NN)
# (NP head/NN)
# (NP the/DT end/NN)
# (NP head/NN)
# (NP mind/NN)
# (NP blowing/NN)
# (NP the/DT entire/JJ story/NN)
# (NP meaning/NN)
# (NP The/DT movie/NN)
# (NP a/DT short/JJ lived/NN)
# (NP brief/JJ happy/JJ moment/NN)
# (NP the/DT tiny/JJ plotline/NN)
# (NP Dr./NNP)
# (NP the/DT whole/NN)
# (NP the/DT movie/NN)
# (NP the/DT decade/NN)
# (NP The/DT decade/NN)
# (NP any/DT movie/NN)
# (NP the/DT league/NN)
# (NP thrilling/JJ movie/NN)
# (NP till/NN)
# (NP date/NN)
# (NP Grade/NN)
# (NP A+/NNP Label/NNP)
# (NP All/DT time/NN)
# (NP rewatchability/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  No one likes to be messed with.
# Rating: 10
# (NP A/NNP)
# (NP film/NN)
# (NP the/DT film/NN)
# (NP community/NN)
# (NP A/DT film/NN)
# (NP A/NNP)
# (NP film/NN)
# (NP A/DT movie/NN)
# (NP no/DT one/NN)
# (NP Silence/NN)
# (NP Lambs/NNP)
# (NP no/DT coincidence/NN)
# (NP a/DT book/NN)
# (NP baby/NN)
# (NP mystic/JJ river/NN)
# (NP a/DT book/NN)
# (NP the/DT reader/NN)
# (NP dizzy/NN)
# (NP film/NN)
# (NP counterpart/NN)
# (NP the/DT director/NN)
# (NP chair/NN)
# (NP a/DT movie/NN)
# (NP The/DT master/NN)
# (NP suspense/NN)
# (NP influence/NN)
# (NP this/DT film/NN)
# (NP no/DT wonder/NN)
# (NP works/NN)
# (NP the/DT crew/NN)
# (NP the/DT cliff/NN)
# (NP scream/NN)
# (NP a/DT film/NN)
# (NP crawls/NN)
# (NP storm/NN)
# (NP the/DT island/NN)
# (NP classic/JJ film/NN)
# (NP noir/NN)
# (NP The/DT story/NN)
# (NP Marshall/NNP)
# (NP partner/NN)
# (NP this/DT mysterious/JJ island/NN)
# (NP fog/NN)
# (NP an/DT escape/NN)
# (NP a/DT dark/NN)
# (NP creepy/JJ premise/NN)
# (NP the/DT whole/JJ movie/NN)
# (NP this/DT story/NN)
# (NP a/DT scared/JJ man/NN)
# (NP a/DT man/NN)
# (NP war/NN)
# (NP violence/NN)
# (NP the/DT story/NN)
# (NP quest/NN)
# (NP every/DT dark/NN)
# (NP corridor/NN)
# (NP the/DT puzzle/NN)
# (NP the/DT audience/NN)
# (NP the/DT moment/NN)
# (NP conclusion/NN)
# (NP this/DT thriller/NN)
# (NP something/NN)
# (NP the/DT audience/NN)
# (NP a/DT complete/JJ assault/NN)
# (NP a/DT film/NN)
# (NP another/DT thing/NN)
# (NP this/DT apart/NN)
# (NP a/DT horror/NN)
# (NP film/NN)
# (NP this/DT day/NN)
# (NP age/NN)
# (NP terrible/JJ esp/NN)
# (NP these/DT new/JJ gore/NN)
# (NP horror/NN)
# (NP ultimate/JJ goal/NN)
# (NP a/DT film/NN)
# (NP a/DT second/JJ time/NN)
# (NP fact/NN)
# (NP the/DT second/JJ time/NN)
# (NP that/DT puzzle/NN)
# (NP the/DT first/JJ time/NN)
# (NP the/DT audience/NN)
# (NP Well/NNP)
# (NP the/DT second/JJ viewing/NN)
# (NP A/NNP)
# (NP film/NN)
# (NP own/JJ sanity/NN)
# (NP A/DT film/NN)
# (NP A/NNP)
# (NP film/NN)
# (NP the/DT thriller/NN)
# (NP genre/NN)
# (NP A/DT film/NN)
# (NP the/DT main/JJ character/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  All it Takes is One Line of Dialogue to Make an Impact...
# Rating: 9
# (NP line/NN)
# (NP dialogue/NN)
# (NP the/DT end/NN)
# (NP the/DT emotion/NN)
# (NP the/DT film/NN)
# (NP the/DT novel/NN)
# (NP the/DT film/NN)
# (NP this/DT film/NN)
# (NP store/NN)
# (NP film/NN)
# (NP brief/JJ piece/NN)
# (NP dialogue/NN)
# (NP conclusion/NN)
# (NP different/JJ perception/NN)
# (NP the/DT final/JJ act/NN)
# (NP The/DT rest/NN)
# (NP the/DT film/NN)
# (NP great/JJ story/NN)
# (NP film/NN)
# (NP the/DT source/NN)
# (NP material/NN)
# (NP justice/NN)
# (NP a/DT distinctive/JJ experience/NN)
# (NP the/DT book/NN)
# (NP the/DT first/JJ time/NN)
# (NP the/DT menacing/NN)
# (NP atmosphere/NN)
# (NP the/DT island/NN)
# (NP film/NN)
# (NP Every/DT location/NN)
# (NP unseen/JJ danger/NN)
# (NP The/DT lighthouse/NN)
# (NP the/DT civil/JJ war/NN)
# (NP fort/NN)
# (NP housing/NN)
# (NP the/DT island/NN)
# (NP every/DT locale/NN)
# (NP the/DT same/JJ time/NN)
# (NP that/DT personal/JJ fear/NN)
# (NP eerie/NN)
# (NP Descent/NNP)
# (NP such/JJ picture/NN)
# (NP An/DT confined/JJ island/NN)
# (NP a/DT terrific/JJ horror/NN)
# (NP location/NN)
# (NP own/JJ type/NN)
# (NP fear/NN)
# (NP The/DT utter/JJ desperation/NN)
# (NP a/DT persistent/NN)
# (NP nightmare/NN)
# (NP something/NN)
# (NP the/DT audience/NN)
# (NP a/DT movie/NN)
# (NP the/DT horror/thriller/NN)
# (NP genre/NN)
# (NP no/DT small/JJ part/NN)
# (NP the/DT screenplay/NN)
# (NP kind/NN)
# (NP lack/NN)
# (NP character/NN)
# (NP any/DT real/JJ sense/NN)
# (NP suspense/NN)
# (NP this/DT film/NN)
# (NP tension/NN)
# (NP mindless/JJ action/NN)
# (NP a/DT well-deserved/JJ frenetic/JJ scene/NN)
# (NP violence/NN)
# (NP awhile/NN)
# (NP the/DT advantage/NN)
# (NP running/NN)
# (NP gunning/NN)
# (NP the/DT facility/NN)
# (NP faculty/NN)
# (NP the/DT mood/NN)
# (NP this/DT movie/NN)
# (NP check/NN)
# (NP mood/NN)
# (NP spooky/NN)
# (NP full/JJ force/NN)
# (NP A/DT considerable/JJ amount/NN)
# (NP that/DT spooky/NN)
# (NP collection/NN)
# (NP the/DT art/NN)
# (NP creepy/NN)
# (NP the/DT cast/NN)
# (NP Room/NNP)
# (NP Windows/NNP)
# (NP list/NN)
# (NP that/DT note/NN)
# (NP Was/NNP)
# (NP a/DT secret/JJ pact/NN)
# (NP Whether/NNP)
# (NP soul/NN)
# (NP every/DT single/JJ scene/NN)
# (NP this/DT great/JJ talent/NN)
# (NP front/NN)
# (NP the/DT camera/NN)
# (NP anything/NN)
# (NP a/DT faithful/JJ orchestrator/NN)
# (NP the/DT movie/NN)
# (NP the/DT right/JJ direction/NN)
# (NP best/JJS works/NNS)
# (NP style/NN)
# (NP something/NN)
# (NP the/DT presentation/NN)
# (NP the/DT editing/NN)
# (NP the/DT opening/NN)
# (NP scene/NN)
# (NP the/DT audience/NN)
# (NP the/DT scene/NN)
# (NP the/DT way/NN)
# (NP the/DT film/NN)
# (NP a/DT body/NN)
# (NP work/NN)
# (NP company/NN)
# (NP The/DT good/JJ news/NN)
# (NP a/DT place/NN)
# (NP resume/NN)
# (NP Goodfellas/NNP)
# (NP Raging/NNP Bull/NNP)
# (NP no/DT problem/NN)
# (NP side/NN)
# (NP side/NN)
# (NP The/DT Last/JJ Temptation/NN)
# (NP Bringing/NNP Out/NNP)
# (NP Dead/NNP)
# (NP The/DT cinematography/NN)
# (NP ugly/JJ presentation/NN)
# (NP modern/JJ horror/NN)
# (NP bright/JJ color/NN)
# (NP daytime/NN)
# (NP dream/NN)
# (NP a/DT distinct/JJ feeling/NN)
# (NP terror/NN)
# (NP a/DT pretty/JJ face/NN)
# (NP a/DT great/JJ story/NN)
# (NP boot/NN)
# (NP the/DT film/NN)
# (NP the/DT source/NN)
# (NP material/NN)
# (NP the/DT movie/NN)
# (NP the/DT film/NN)
# (NP television/NN)
# (NP the/DT silver/NN)
# (NP screen/NN)
# (NP the/DT film/NN)
# (NP the/DT story/NN)
# (NP the/DT know/NN)
# (NP paranoia/NN)
# (NP phobia/NN)
# (NP the/DT camera/NN)
# (NP the/DT mental/NN)
# (NP the/DT luckiest/JJS authors/NNS)
# (NP the/DT planet/NN)
# (NP work/NN)
# (NP the/DT big/JJ screen/NN)
# (NP work/NN)
# (NP such/JJ treatment/NN)
# (NP the/DT risk/NN)
# (NP plot/NN)
# (NP the/DT book/NN)
# (NP section/NN)
# (NP tags/NN)
# (NP this/DT story/NN)
# (NP any/DT length/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  The movie is perfect psycho drama
# Rating: 10
# (NP the/DT story/NN)
# (NP A/NNP)
# (NP federal/JJ marshal/NN)
# (NP the/DT island/NN)
# (NP partner/NN)
# (NP the/DT disappearance/NN)
# (NP a/DT patient/NN)
# (NP Each/DT scene/NN)
# (NP a/DT turn/NN)
# (NP whilst/JJ searching/NN)
# (NP Dr./NNP Cawley/NNP)
# (NP wife/NN)
# (NP the/DT movie/NN)
# (NP plot/NN)
# (NP controversy/NN)
# (NP this/DT film/NN)
# (NP a/DT film/NN)
# (NP a/DT second/JJ time/NN)
# (NP fact/NN)
# (NP the/DT second/JJ time/NN)
# (NP that/DT puzzle/NN)
# (NP the/DT first/JJ time/NN)
# (NP the/DT audience/NN)
# (NP Well/NNP)
# (NP the/DT second/JJ viewing/NN)
# (NP A/NNP)
# (NP film/NN)
# (NP own/JJ sanity/NN)
# (NP A/DT film/NN)
# (NP A/NNP)
# (NP film/NN)
# (NP the/DT thriller/NN)
# (NP genre/NN)
# (NP A/DT film/NN)
# (NP the/DT main/JJ character/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Don't be side tracked by the obvious twist.......there is more than one
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Shutter Island is at the top of its genre
# Rating: 9
# (NP attention/NN)
# (NP every/DT detail/NN)
# (NP this/DT film/NN)
# (NP suspense/NN)
# (NP all/DT time/NN)
# (NP The/DT story/NN)
# (NP The/DT film/NN)
# (NP the/DT edge/NN)
# (NP seat/NN)
# (NP The/DT film/NN)
# (NP everything/NN)
# (NP disposal/NN)
# (NP scenery/NN)
# (NP the/DT film/NN)
# (NP every/DT minute/NN)
# (NP everyone/NN)
# (NP a/DT usual/JJ fan/NN)
# (NP the/DT genre/NN)
# (NP this/DT film/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  I can't look away...
# Rating: 7
# (NP a/DT horror/thriller/NN)
# (NP the/DT crap/NN)
# (NP gore/NN)
# (NP mind/NN)
# (NP this/DT movie/NN)
# (NP lame-duck/JJ PG-13/JJ horror/NN)
# (NP The/DT horror/thriller/NN)
# (NP genre/NN)
# (NP gore/NN)
# (NP the/DT noir/NN)
# (NP terror/NN)
# (NP the/DT '50s/NN)
# (NP '60/NN)
# (NP director/NN)
# (NP full/JJ blast/NN)
# (NP a/DT thriller/NN)
# (NP own/JJ unique/JJ vision/NN)
# (NP The/DT atmosphere/NN)
# (NP the/DT movie/NN)
# (NP the/DT movie/NN)
# (NP attention/NN)
# (NP The/DT scenery/NN)
# (NP no/DT excessive/JJ lighting/NN)
# (NP grain/NN)
# (NP darkness/NN)
# (NP The/DT editing/NN)
# (NP the/DT film/NN)
# (NP lose/JJ focus/NN)
# (NP The/DT movie/NN)
# (NP a/DT book/NN)
# (NP The/DT movie/NN)
# (NP the/DT breathlessness/NN)
# (NP uneasiness/NN)
# (NP the/DT power/NN)
# (NP The/DT music/NN)
# (NP no/DT music/NN)
# (NP the/DT music/NN)
# (NP the/DT scene/NN)
# (NP noirish/JJ thriller/NN)
# (NP style/NN)
# (NP a/DT vengeance/NN)
# (NP today/NN)
# (NP meaning/NN)
# (NP suspense/NN)
# (NP horror/NN)
# (NP the/DT movie/NN)
# (NP top-form/NN)
# (NP DiCaprio/Martin/NNP)
# (NP Scorsese/JJ collaboration/NN)
# (NP the/DT protagonist/NN)
# (NP the/DT audience/NN)
# (NP character/NN)
# (NP a/DT psychological/JJ trip/NN)
# (NP the/DT entire/JJ movie/NN)
# (NP the/DT movie/NN)
# (NP character/NN)
# (NP a/DT stunning/JJ performance/NN)
# (NP Best/NNP Actor/NNP)
# (NP nomination/NN)
# (NP a/DT vivid/JJ portrayal/NN)
# (NP terrified/JJ man/NN)
# (NP cast/NN)
# (NP terrific/NN)
# (NP masterpiece/NN)
# (NP psychological/JJ help/NN)
# (NP the/DT best/JJS films/NNS)
# (NP the/DT year/NN)
# (NP an/DT open/JJ mind/NN)
# (NP Overall/JJ value/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Of all the movies in theatres to see, this is worth your time
# Rating: 9
# (NP this/DT evening/NN)
# (NP release/NN)
# (NP this/DT film/NN)
# (NP intrigue/NN)
# (NP Prior/NNP)
# (NP this/DT film/NN)
# (NP a/DT preconceived/JJ notion/NN)
# (NP this/DT thriller/NN)
# (NP good/JJ marketing/NN)
# (NP the/DT trailer/NN)
# (NP the/DT movie/NN)
# (NP an/DT easy/JJ plot/NN)
# (NP line/NN)
# (NP little/JJ thought/NN)
# (NP This/DT movie/NN)
# (NP the/DT viewer/NN)
# (NP attention/NN)
# (NP the/DT way/NN)
# (NP someone/NN)
# (NP fan/NN)
# (NP performance/NN)
# (NP much/JJ range/NN)
# (NP character/NN)
# (NP fact/NN)
# (NP the/DT acting/NN)
# (NP this/DT film/NN)
# (NP The/DT directing/NN)
# (NP quality/NN)
# (NP this/DT film/NN)
# (NP a/DT film/NN)
# (NP this/DT film/NN)
# (NP the/DT director/NN)
# (NP the/DT plot/NN)
# (NP line/NN)
# (NP viewer/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Great a must watch !!
# Rating: 9
# (NP the/DT film/NN)
# (NP half/NN)
# (NP the/DT book/NN)
# (NP the/DT chance/NN)
# (NP the/DT film/NN)
# (NP the/DT original/JJ material.The/NN)
# (NP directing/NN)
# (NP pretty/JJ cool/NN)
# (NP some/DT cool/JJ camera/NN)
# (NP Dead/NNP)
# (NP great/JJ job/NN)
# (NP everyone/NN)
# (NP top/JJ notch/NN)
# (NP fright/NN)
# (NP film/NN)
# (NP a/DT solid/JJ thriller/NN)
# (NP a/DT good/JJ story/NN)
# (NP film/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Don't miss this one - review from a skeptic.
# Rating: 10
# (NP the/DT look/NN)
# (NP the/DT trailer/NN)
# (NP a/DT horror/NN)
# (NP film/NN)
# (NP a/DT dangerous/JJ place/NN)
# (NP isolation/NN)
# (NP fascist/JJ control/NN)
# (NP U.S/NNP Marshall/NNP)
# (NP an/DT asylum/NN)
# (NP a/DT missing/JJ patient/NN)
# (NP A/DT demon/NN)
# (NP A/DT ghost/NN)
# (NP skeptical/JJ walking/NN)
# (NP the/DT theater/NN)
# (NP this/DT twist/NN)
# (NP water/NN)
# (NP The/DT film/NN)
# (NP new/JJ partner/NN)
# (NP a/DT ferry/NN)
# (NP assignment/NN)
# (NP suspect/NN)
# (NP no/DT additional/JJ development/NN)
# (NP the/DT story/NN)
# (NP an/DT opening/NN)
# (NP montage/NN)
# (NP a/DT couple/NN)
# (NP momentous/JJ development/NN)
# (NP hero/NN)
# (NP the/DT glorified/JJ top/JJ lit/NN)
# (NP smoking/NN)
# (NP a/DT beauty/NN)
# (NP confident/JJ gangster/NN)
# (NP a/DT harsher/JJ character/NN)
# (NP poor/JJ posture/NN)
# (NP someone/NN)
# (NP someone/NN)
# (NP a/DT deep/JJ past/NN)
# (NP the/DT gate/NN)
# (NP Soon/NN)
# (NP Dr/NNP)
# (NP modern/JJ man/NN)
# (NP the/DT asylum/NN)
# (NP the/DT investigation/NN)
# (NP staff/NN)
# (NP something/NN)
# (NP Everyone/NN)
# (NP Evidence/NN)
# (NP hero/NN)
# (NP psychosis/NN)
# (NP this/DT madness/NN)
# (NP the/DT guard/NN)
# (NP Soon/NNP)
# (NP the/DT tip/NN)
# (NP the/DT iceberg/NN)
# (NP own/JJ past/NN)
# (NP a/DT mass/NN)
# (NP conspiracy/NN)
# (NP concentration/NN)
# (NP Though/NNP)
# (NP anything/NN)
# (NP the/DT story/NN)
# (NP injustice/NN)
# (NP role/NN)
# (NP Amongst/NNP)
# (NP a/DT world/NN)
# (NP a/DT master/NN)
# (NP film/NN)
# (NP specialty/NN)
# (NP character/NN)
# (NP story/NN)
# (NP a/DT fresh/JJ balance/NN)
# (NP a/DT mix/NN)
# (NP noir/NN)
# (NP thriller/NN)
# (NP sort/NN)
# (NP a/DT horror/NN)
# (NP movie/NN)
# (NP Shining/NNP)
# (NP trick/NN)
# (NP pony/NN)
# (NP this/DT praise/NN)
# (NP everyone/NN)
# (NP The/DT story/NN)
# (NP some/DT attention/NN)
# (NP a/DT bit/NN)
# (NP course/NN)
# (NP sense/NN)
# (NP film/NN)
# (NP a/DT couple/NN)
# (NP the/DT story/NN)
# (NP a/DT bit/NN)
# (NP this/DT point/NN)
# (NP faith/NN)
# (NP viscosity/NN)
# (NP the/DT story/NN)
# (NP put/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Another Excellent Film by Scorsese...
# Rating: 10
# (NP anyone/NN)
# (NP The/DT man/NN)
# (NP time/NN)
# (NP the/DT actual/JJ movie/NN)
# (NP a/DT early/JJ screening/NN)
# (NP this/DT while/NN)
# (NP a/DT typical/JJ film/NN)
# (NP a/DT different/JJ take/NN)
# (NP the/DT director/NN)
# (NP every/DT film/NN)
# (NP own/JJ league/NN)
# (NP film-making/NN)
# (NP anything/NN)
# (NP a/DT great/JJ start/NN)
# (NP a/DT great/JJ film/NN)
# (NP The/DT acting/NN)
# (NP every/DT character/NN)
# (NP none/NN)
# (NP place/NN)
# (NP The/DT script/NN)
# (NP a/DT while/NN)
# (NP exception/NN)
# (NP Basterds/NNP)
# (NP Everything/NN)
# (NP the/DT set/NN)
# (NP lighting/NN)
# (NP everyone/NN)
# (NP typical/JJ movie/NN)
# (NP this/DT film/NN)
# (NP a/DT compelling/NN)
# (NP thought-provoking/JJ experience/NN)
# (NP further/JJ clarity/NN)
# (NP mind/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Which Would Be Worse, To Live As A Monster Or To Die As A Good Man?
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Counting down the days until I can add this to my DVD collection...
# Rating: 9
# (NP rating/NN)
# (NP this/DT film/NN)
# (NP this/DT movie/NN)
# (NP first/JJ Scorsese/JJ film/NN)
# (NP the/DT genius/NN)
# (NP this/DT showing/NN)
# (NP brilliance/NN)
# (NP a/DT captivating/NN)
# (NP storyline/NN)
# (NP the/DT release/NN)
# (NP a/DT press/NN)
# (NP release/NN)
# (NP that/DT news/NN)
# (NP the/DT story/NN)
# (NP A/NNP)
# (NP federal/JJ marshall/NN)
# (NP the/DT island/NN)
# (NP partner/NN)
# (NP the/DT disappearance/NN)
# (NP a/DT patient/NN)
# (NP Each/DT scene/NN)
# (NP a/DT turn/NN)
# (NP whilst/JJ searching/NN)
# (NP Dr./NNP Cawley/NNP)
# (NP wife/NN)
# (NP the/DT movie/NN)
# (NP plot/NN)
# (NP controversy/NN)
# (NP this/DT film/NN)
# (NP the/DT plot/NN)
# (NP everything/NN)
# (NP fruition/NN)
# (NP the/DT movie/NN)
# (NP anything/NN)
# (NP word/NN)
# (NP any/DT Scorsese/JJ movie/NN)
# (NP the/DT past/NN)
# (NP surrealism/NN)
# (NP an/DT intense/JJ thriller/NN)
# (NP the/DT mind/NN)
# (NP corrode/NN)
# (NP this/DT film/NN)
# (NP the/DT trailer/NN)
# (NP a/DT horror/NN)
# (NP film/NN)
# (NP a/DT lot/NN)
# (NP jumpy/NN)
# (NP the/DT same/JJ feeling/NN)
# (NP the/DT shock/NN)
# (NP much/JJ detail/NN)
# (NP the/DT risk/NN)
# (NP seat/NN)
# (NP scare/NN)
# (NP work/NN)
# (NP movie/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Another Martin-Leo Masterpiece!!!
# Rating: 8
# (NP film/NN)
# (NP making/NN)
# (NP the/DT academy/NN)
# (NP award/NN)
# (NP Departed/NNP)
# (NP fav/NN)
# (NP star/NN)
# (NP DiCaprio../NNP)
# (NP This/DT time/NN)
# (NP different/JJ script/NN)
# (NP the/DT audience/NN)
# (NP the/DT first/JJ scene/NN)
# (NP The/DT movie/NN)
# (NP saw/NN)
# (NP film/NN)
# (NP festival/NN)
# (NP the/DT plot/NN)
# (NP no/DT stone/NN)
# (NP talented/JJ actor/NN)
# (NP every/DT movie/NN)
# (NP the/DT role/NN)
# (NP a/DT terrific/JJ performance/NN)
# (NP every/DT time/NN)
# (NP the/DT head/NN)
# (NP psychiatrist/NN)
# (NP the/DT asylum/NN)
# (NP a/DT marvelous/JJ job/NN)
# (NP The/DT film/NN)
# (NP dream/NN)
# (NP location/NN)
# (NP the/DT island/NN)
# (NP the/DT concentration/NN)
# (NP camp/NN)
# (NP The/DT audience/NN)
# (NP a/DT world/NN)
# (NP reality/NN)
# (NP dream/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Once again, Scorsese has helped redefine a genre'
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Scorsese throws a curve ball; audience strikes out
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  The Cabinet of Dr. Shutter Island - spoiler alert
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Disappointing Ending
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Did I miss something?
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  So boring you'll question your sanity
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Scorsese Lays a Very Large Rotten Egg
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  The Good and The Bad
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  A Horrible Movie
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Completely idiotic
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: Shutter Island
# Review heading:  Boring and pretentious
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  James McAvoy Carries This Film
# Rating: 8
# (NP A/DT fantastic/JJ performance/NN)
# (NP the/DT film/NN)
# (NP star/NN)
# (NP reason/NN)
# (NP this/DT film/NN)
# (NP Every/DT personality/NN)
# (NP display/NN)
# (NP Anya/NNP)
# (NP breath-taking/NN)
# (NP a/DT fine/JJ job/NN)
# (NP a/DT film/NN)
# (NP M./NNP Night/NNP Shyamalan/NNP)
# (NP a/DT serious/JJ director/NN)
# (NP a/DT string/NN)
# (NP the/DT sequel/NN)
# (NP the/DT conclusion/NN)
# (NP series/NN)
# (NP January/NNP)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Great movie! James McAvoy is awesome.
# Rating: 8
# (NP This/DT movie/NN)
# (NP the/DT next/JJ character/NN)
# (NP performance/NN)
# (NP a/DT man/NN)
# (NP every/DT part/NN)
# (NP The/DT end/NN)
# (NP anything/NN)
# (NP Well/NNP)
# (NP today/NN)
# (NP the/DT mistake/NN)
# (NP a/DT different/JJ movie/NN)
# (NP the/DT worst/JJS movies/NNS)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  It maybe gets a bit too fantastical, but it's still an awesome thriller
# Rating: 8
# (NP this/DT movie/NN)
# (NP last/JJ year/NN)
# (NP consideration/NN)
# (NP the/DT plot/NN)
# (NP a/DT man/NN)
# (NP dissociative/JJ identity/NN)
# (NP disorder/NN)
# (NP this/DT movie/NN)
# (NP this/DT movie/NN)
# (NP a/DT bit/NN)
# (NP an/DT awesome/JJ thriller/NN)
# (NP The/DT movie/NN)
# (NP an/DT awesome/JJ acting/NN)
# (NP a/DT weird/JJ feeling/NN)
# (NP something/NN)
# (NP the/DT viewer/NN)
# (NP this/DT thriller/NN)
# (NP a/DT good/JJ way/NN)
# (NP a/DT unrealistic/JJ representation/NN)
# (NP dissociative/JJ identity/NN)
# (NP disorder/NN)
# (NP a/DT big/JJ turnoff/NN)
# (NP a/DT great/JJ movie/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Great story telling
# Rating: 10
# (NP a/DT remarkable/JJ film/NN)
# (NP The/DT premise/NN)
# (NP the/DT film/NN)
# (NP beneath/NN)
# (NP a/DT horror/NN)
# (NP film/NN)
# (NP an/DT action/NN)
# (NP flick/NN)
# (NP any/DT car/NN)
# (NP A/DT high-tension/JJ psychological/JJ thriller/NN)
# (NP every/DT explanation/NN)
# (NP The/DT acting/NN)
# (NP the/DT script/NN)
# (NP the/DT cinematography/NN)
# (NP the/DT music/sound/NN)
# (NP the/DT tension/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Shyamalan Is Back!
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Love that he's back!
# Rating: 8
# (NP M.Night/NNP Shyamalan/NNP)
# (NP work/NN)
# (NP Happening/NNP)
# (NP a/DT terrible/JJ movie/NN)
# (NP No/DT comment/NN)
# (NP Airbender/NNP)
# (NP a/DT wonderful/JJ comeback/NN)
# (NP ability/NN)
# (NP much/JJ fun/NN)
# (NP The/DT cinematography/NN)
# (NP the/DT story/NN)
# (NP a/DT great/JJ performance/NN)
# (NP this/DT film/NN)
# (NP any/DT thriller/NN)
# (NP M.Night/NNP)
# (NP this/DT point/NN)
# (NP a/DT horror/NN)
# (NP film/NN)
# (NP skin/NN)
# (NP Ring/NNP)
# (NP Ca/NNP)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  they didn't get it
# Rating: 10
# (NP this/DT movie/NN)
# (NP material/NN)
# (NP Oscar/NNP)
# (NP movie/NN)
# (NP citizen/JJ kane/NN)
# (NP the/DT bruce/NN)
# (NP willis/NN)
# (NP cameo/NN)
# (NP a/DT cinematic/JJ universe/NN)
# (NP This/DT film/NN)
# (NP an/DT amazing/JJ performance/NN)
# (NP plot/NN)
# (NP no/DT twist/JJ end/NN)
# (NP a/DT bitter/JJ end/NN)
# (NP this/DT time/NN)
# (NP a/DT while/NN)
# (NP the/DT movie/NN)
# (NP a/DT desperation/NN)
# (NP a/DT ray/NN)
# (NP light/NN)
# (NP The/DT film/NN)
# (NP a/DT subtle/JJ commentary/NN)
# (NP violence/NN)
# (NP abuse/NN)
# (NP human/JJ nature/NN)
# (NP sexism/NN)
# (NP modern/JJ society/NN)
# (NP the/DT potential/NN)
# (NP racism/NN)
# (NP the/DT idiocy/NN)
# (NP traumas/NN)
# (NP madness/NN)
# (NP the/DT virtue/NN)
# (NP patience/NN)
# (NP existential/JJ angst/NN)
# (NP etc/NN)
# (NP a/DT horror/NN)
# (NP movie/NN)
# (NP a/DT sick/JJ person/NN)
# (NP common/JJ trope/NN)
# (NP horror/NN)
# (NP this/DT film/NN)
# (NP the/DT trope/NN)
# (NP back/NN)
# (NP a/DT charming/JJ psychopath/NN)
# (NP morality/NN)
# (NP an/DT ambivalent/JJ point/NN)
# (NP view/NN)
# (NP The/DT movie/NN)
# (NP a/DT taboo/NN)
# (NP this/DT narration/NN)
# (NP an/DT act/NN)
# (NP God/NNP)
# (NP some/DT creature/NN)
# (NP the/DT protagonist/NN)
# (NP a/DT couple/NN)
# (NP delightful/NN)
# (NP thing/NN)
# (NP This/DT movie/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  I don't understand the hate for this film
# Rating: 8
# (NP work/NN)
# (NP this/DT movie/NN)
# (NP vision/NN)
# (NP another/DT chance/NN)
# (NP this/DT movie/NN)
# (NP movie/NN)
# (NP own/JJ decision/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  A great suspense story, with a standout performance by Mr McEvoy
# Rating: 9
# (NP A/DT welcome/JJ return/NN)
# (NP the/DT director/NN)
# (NP finest/JJS performances/NNS)
# (NP the/DT film/NN)
# (NP level/NN)
# (NP studio/NN)
# (NP no/DT matter/NN)
# (NP range/NN)
# (NP talent/NN)
# (NP surprising/NN)
# (NP another/DT level/NN)
# (NP the/DT film/NN)
# (NP a/DT great/JJ film/NN)
# (NP the/DT theater/NN)
# (NP suspense/NN)
# (NP this/DT story/NN)
# (NP the/DT edge/NN)
# (NP seat/NN)
# (NP a/DT suspense/JJ mode/NN)
# (NP the/DT film/NN)
# (NP a/DT typical/JJ kidnapping/NN)
# (NP film/NN)
# (NP the/DT director/NN)
# (NP the/DT film/NN)
# (NP the/DT end/NN)
# (NP this/DT case/NN)
# (NP earlier/JJR films/NNS)
# (NP imagination/NN)
# (NP work/NN)
# (NP great/JJ attention/NN)
# (NP a/DT great/JJ film/NN)
# (NP an/DT original/JJ suspense/thriller/NN)
# (NP go/NN)
# (NP a/DT review/NN)
# (NP this/DT film/NN)
# (NP the/DT mark/NN)
# (NP this/DT time/NN)
# (NP round/NN)
# (NP opinion/NN)
# (NP M/NNP Night/NNP)
# (NP budget/NN)
# (NP work/NN)
# (NP storytelling/NN)
# (NP McEvoy/NNP)
# (NP the/DT risk/NN)
# (NP Q/NNP)
# (NP A/NNP)
# (NP a/DT decent/JJ humble/NN)
# (NP man/NN)
# (NP such/JJ resonance/NN)
# (NP skill/NN)
# (NP a/DT great/JJ performance/NN)
# (NP a/DT talent/NN)
# (NP the/DT see/NN)
# (NP the/DT film/NN)
# (NP the/DT threatre/NN)
# (NP a/DT big/JJ screen/NN)
# (NP the/DT edge/NN)
# (NP seat/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  And I Thought M. Night Shyamalan Was Loosing His Touch.
# Rating: 7
# (NP this/DT film/NN)
# (NP first/JJ debut/NN)
# (NP M./NNP Night/NNP)
# (NP touch/NN)
# (NP a/DT bit/NN)
# (NP everything/NN)
# (NP M./NNP Night/NNP)
# (NP chance/NN)
# (NP Split/NNP)
# (NP M./NNP Night/NNP)
# (NP the/DT way/NN)
# (NP the/DT unpredictable/JJ story-line/NN)
# (NP the/DT edge/NN)
# (NP seat/NN)
# (NP a/DT great/JJ horror/thriller/NN)
# (NP fetched/JJ psychological/JJ thriller/NN)
# (NP the/DT plot/NN)
# (NP the/DT end/NN)
# (NP M./NNP Night/NNP)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Don't believe the One Star reviews...
# Rating: 8
# (NP this/DT movie/NN)
# (NP star/NN)
# (NP a/DT return/NN)
# (NP the/DT director/NN)
# (NP SENSE/NNP)
# (NP output/NN)
# (NP AIRBENDER/NNP)
# (NP HAPPENING/NNP)
# (NP star/NN)
# (NP higher/JJR marks/NNS)
# (NP the/DT average/NN)
# (NP a/DT lot/NN)
# (NP fun/NN)
# (NP a/DT subgenre/NN)
# (NP ie/JJ dissociative/NN)
# (NP identity/NN)
# (NP disorder/NN)
# (NP a/DT great/JJ performance/NN)
# (NP this/DT film/NN)
# (NP outstanding/JJ performance/NN)
# (NP supporting/JJ role/NN)
# (NP SENSE/NNP)
# (NP No/NNP)
# (NP this/DT distort/NN)
# (NP mental/JJ illness/NN)
# (NP that/DT subject/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Not Perfect But Good
# Rating: 7
# (NP this/DT film/NN)
# (NP no/DT way/NN)
# (NP perfect/NN)
# (NP the/DT film/NN)
# (NP anything/NN)
# (NP violent/NN)
# (NP this/DT film/NN)
# (NP kind/NN)
# (NP The/DT acting/NN)
# (NP The/DT plot/NN)
# (NP the/DT only/JJ thing/NN)
# (NP a/DT little/JJ confusing/NN)
# (NP a/DT great/JJ thriller/NN)
# (NP film/NN)
# (NP entertaining/NN)
# (NP the/DT director/NN)
# (NP next/JJ film/NN)
# (NP next/JJ film/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Rating: A
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Split not only has Shyamalan back on the saddle but also rewards fans for their patience in his return to form.
# Rating: 8
# (NP a/DT terrific/JJ comeback/NN)
# (NP Many/NNP)
# (NP horror/NN)
# (NP writer-director/NN)
# (NP M./NNP Night/NNP)
# (NP a/DT downward/JJ spiral/NN)
# (NP own/JJ superhero/NN)
# (NP film/NN)
# (NP the/DT continuation/NN)
# (NP tryst/NN)
# (NP a/DT long/JJ awaited/JJ rhetoric/NN)
# (NP this/DT filmmaker/NN)
# (NP the/DT right/JJ moment/NN)
# (NP last/JJ film/NN)
# (NP prowess/NN)
# (NP the/DT high/JJ level/NN)
# (NP creativity/NN)
# (NP a/DT household/NN)
# (NP name/NN)
# (NP contemporary/JJ horror/NN)
# (NP a/DT comeback/NN)
# (NP a/DT tactical/JJ setup/NN)
# (NP own/JJ cinematic/JJ universe/NN)
# (NP the/DT film/NN)
# (NP a/DT person/NN)
# (NP each/DT personality/NN)
# (NP full/JJ awareness/NN)
# (NP the/DT rest/NN)
# (NP main/JJ character/NN)
# (NP a/DT handful/NN)
# (NP the/DT film/NN)
# (NP fashionista/NN)
# (NP darker/NN)
# (NP the/DT abduction/NN)
# (NP high/JJ school/NN)
# (NP a/DT ritualistic/JJ sacrifice/NN)
# (NP personality/NN)
# (NP Beast/NNP)
# (NP time/NN)
# (NP fear/NN)
# (NP escape/NN)
# (NP protagonist/NN)
# (NP Taylor-Joy/NNP)
# (NP proactive/JJ deconstruct/NN)
# (NP advantage/NN)
# (NP revelatory/NN)
# (NP the/DT first/JJ time/NN)
# (NP a/DT monster/NN)
# (NP debut/NN)
# (NP film/NN)
# (NP wait/NN)
# (NP till/NN)
# (NP a/DT load/NN)
# (NP an/DT outstanding/JJ performance/NN)
# (NP versatility/NN)
# (NP dozen/NN)
# (NP film/NN)
# (NP role/NN)
# (NP broad/JJ range/NN)
# (NP this/DT film/NN)
# (NP a/DT familiar/JJ antagonist/NN)
# (NP a/DT nerve/NN)
# (NP supervillain/NN)
# (NP called/JJ signature/NN)
# (NP twist/NN)
# (NP an/DT actual/JJ twist/NN)
# (NP the/DT story/NN)
# (NP seamless/JJ integration/NN)
# (NP a/DT sort/NN)
# (NP trilogy/NN)
# (NP most/JJS viewers/NNS)
# (NP an/DT inside/JJ joke/NN)
# (NP Easter/NNP)
# (NP egg/NN)
# (NP every/DT true/JJ fan/NN)
# (NP the/DT man/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  The movie that got me interested into film!
# Rating: 10
# (NP first/JJ review/NN)
# (NP the/DT movie/NN)
# (NP film/NN)
# (NP movie/NN)
# (NP couch/NN)
# (NP halloween/NN)
# (NP a/DT horror/NN)
# (NP film/NN)
# (NP section/NN)
# (NP the/DT page/NN)
# (NP the/DT plot/NN)
# (NP synopsis/NN)
# (NP the/DT concept/NN)
# (NP the/DT film/NN)
# (NP the/DT first/JJ time/NN)
# (NP movie/NN)
# (NP seat/NN)
# (NP the/DT whole/JJ time/NN)
# (NP the/DT film/NN)
# (NP the/DT movie/NN)
# (NP attention/NN)
# (NP the/DT interesting/JJ camera/NN)
# (NP the/DT cinematographer/NN)
# (NP the/DT film/NN)
# (NP M./NNP Night/NNP Shyamalan/NNP)
# (NP love/NN)
# (NP film/NN)
# (NP this/DT film/NN)
# (NP an/DT oscar/NN)
# (NP worthy/JJ performance/NN)
# (NP good/JJ performance/NN)
# (NP this/DT film/NN)
# (NP interesting/JJ character/NN)
# (NP building/NN)
# (NP suspense/NN)
# (NP this/DT movie/NN)
# (NP the/DT cinematography/NN)
# (NP this/DT film/NN)
# (NP The/DT story/NN)
# (NP this/DT film/NN)
# (NP twist/NN)
# (NP the/DT twist/NN)
# (NP the/DT internet/NN)
# (NP a/DT character/NN)
# (NP movie/NN)
# (NP a/DT treat/NN)
# (NP passion/NN)
# (NP film/NN)
# (NP all/DT time/NN)
# (NP a/DT film/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Superb Acting by James McAvoy, but don't hold your breath for the twist
# Rating: 7
# (NP The/DT only/JJ reason/NN)
# (NP this/DT movie/NN)
# (NP the/DT amazing/JJ performance/NN)
# (NP minimal/JJ change/NN)
# (NP physical/JJ appearance/NN)
# (NP superb/NN)
# (NP acting/NN)
# (NP scene/NN)
# (NP character/NN)
# (NP the/DT drop/NN)
# (NP a/DT hat/NN)
# (NP The/DT twist/NN)
# (NP the/DT end/NN)
# (NP the/DT movie/NN)
# (NP Unbreakable/NNP)
# (NP the/DT twist/NN)
# (NP this/DT movie/NN)
# (NP M./NNP Night/NNP)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Multiple Scares
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  I always look forward on watching this movie
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  A Dude With TOO Much Personality....
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  A twisty, tense thriller that doubles as a superb showcase for McAvoy's talents
# Rating: 8
# (NP a/DT director/NN)
# (NP lady/NN)
# (NP Water/NNP)
# (NP Happening/NNP)
# (NP Airbender/NNP)
# (NP horror/NN)
# (NP a/DT renaissance/NN)
# (NP the/DT auteur/NN)
# (NP Shyamalan/NNP)
# (NP twist/NN)
# (NP significant/JJ budget/NN)
# (NP loopy/JJ creative/JJ ambition/NN)
# (NP card/NN)
# (NP fortuitous/JJ run/NN)
# (NP the/DT disorder/NN)
# (NP a/DT true/JJ story/NN)
# (NP a/DT man/NN)
# (NP male/NN)
# (NP insulin/NN)
# (NP The/DT catch/NN)
# (NP all/DT hell/NN)
# (NP an/DT actor/NN)
# (NP dream/NN)
# (NP job/NN)
# (NP the/DT opportunity/NN)
# (NP the/DT nth/JJ degree/NN)
# (NP the/DT challenge/NN)
# (NP a/DT performance/NN)
# (NP versatility/NN)
# (NP The/DT film/NN)
# (NP performance/NN)
# (NP The/DT plot/NN)
# (NP tense/JJ kidnapping/hostage/NN)
# (NP situation/NN)
# (NP a/DT doctor/NN)
# (NP an/DT expert/NN)
# (NP a/DT narrative/JJ purpose/NN)
# (NP this/DT doctor/NN)
# (NP the/DT movie/NN)
# (NP something/NN)
# (NP a/DT halt/NN)
# (NP interesting/JJ story/NN)
# (NP the/DT movie/NN)
# (NP distinctive/JJ style/NN)
# (NP an/DT ominous/JJ score/NN)
# (NP trick/NN)
# (NP pony/NN)
# (NP addition/NN)
# (NP a/DT way/NN)
# (NP tension/NN)
# (NP guard/NN)
# (NP a/DT bizarre/JJ joke/NN)
# (NP a/DT terrific/JJ tactic/NN)
# (NP the/DT film/NN)
# (NP recommendation/NN)
# (NP the/DT film/NN)
# (NP third/JJ act/NN)
# (NP something/NN)
# (NP twist/NN)
# (NP twist/NN)
# (NP a/DT thrilling/JJ sense/NN)
# (NP chaos/NN)
# (NP dread/NN)
# (NP al/NN)
# (NP a/DT worthy/JJ work/NN)
# (NP a/DT jolt/NN)
# (NP high/JJ octane/NN)
# (NP the/DT doldrums/NN)
# (NP January/NNP)
# (NP dumping/NN)
# (NP ground/NN)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  It Took Him Over a Decade but Shyamalan Finally Made Another Good Movie
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Terrible movie NOTE: **May Contain Spoilers**
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  What A Stinker!!!
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  What was that???
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Movie: split
# Review heading:  Don't waste your money ...it's time to stop supporting his crap flicks
# Rating:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
tbl_imdb
# Out:
#         Movie_Name                                       Review_Title  \
# 0            sybil   Vivid, unsettling true story given enormous s...
# 1            sybil   More than 20 years later, I still remember th...
# 2            sybil       Shoe-hooks, white coats and the Big Chair...
# 3            sybil                                    Excellent Movie
# 4            sybil             A fascinating movie detailing Behavior
# 5            sybil     I can't emphasize how underrated this film is!
# 6            sybil               A Modern Masterpiece of movie making
# 7            sybil                                    Endearing Sybil
# 8            sybil   Split personality as a metaphor for what we m...
# 9            sybil                    Jessamine Milner, the "Grandma"
# 10           sybil         My God ! What did that monster do to you!?
# 11           sybil   Sybil DVD was both informative and disappointing
# 12           sybil                   Get this MOVIE on DVD, PLEASE!!!
# 13           sybil                  Deeply haunting movie.Amazing....
# 14           sybil   One of the greatest psychological dramas ever...
# 15           sybil                             A Triumph In Every Way
# 16           sybil                                        Great Movie
# 17           sybil   Very good movie!!!!!!! I would watch again an...
# 18           sybil   If you liked this film you must read Flora Rh...
# 19           sybil   I count this movie to be in an elite group of...
# 20           sybil                                        Still fresh
# 21           sybil                                              Sybil
# 22           sybil   An excellent movie, but it is too hard to fin...
# 23           sybil                            This Movie is Damn Good
# 24           sybil                          Definitely worth the buy!
# 25  Shutter Island                               Movie of the decade.
# 26  Shutter Island                    No one likes to be messed with.
# 27  Shutter Island   All it Takes is One Line of Dialogue to Make ...
# 28  Shutter Island                  The movie is perfect psycho drama
# 29  Shutter Island   Don't be side tracked by the obvious twist......
# ..             ...                                                ...
# 45  Shutter Island              Scorsese Lays a Very Large Rotten Egg
# 46  Shutter Island                               The Good and The Bad
# 47  Shutter Island                                   A Horrible Movie
# 48  Shutter Island                                 Completely idiotic
# 49  Shutter Island                             Boring and pretentious
# 50           split                     James McAvoy Carries This Film
# 51           split              Great movie! James McAvoy is awesome.
# 52           split   It maybe gets a bit too fantastical, but it's...
# 53           split                                Great story telling
# 54           split                                 Shyamalan Is Back!
# 55           split                               Love that he's back!
# 56           split                                 they didn't get it
# 57           split          I don't understand the hate for this film
# 58           split   A great suspense story, with a standout perfo...
# 59           split   And I Thought M. Night Shyamalan Was Loosing ...
# 60           split              Don't believe the One Star reviews...
# 61           split                               Not Perfect But Good
# 62           split                                          Rating: A
# 63           split   Split not only has Shyamalan back on the sadd...
# 64           split        The movie that got me interested into film!
# 65           split   Superb Acting by James McAvoy, but don't hold...
# 66           split                                    Multiple Scares
# 67           split       I always look forward on watching this movie
# 68           split               A Dude With TOO Much Personality....
# 69           split   A twisty, tense thriller that doubles as a su...
# 70           split   It Took Him Over a Decade but Shyamalan Final...
# 71           split      Terrible movie NOTE: **May Contain Spoilers**
# 72           split                                  What A Stinker!!!
# 73           split                                   What was that???
# 74           split   Don't waste your money ...it's time to stop s...
#
#                                           Review_Desc Review_Rating  \
# 0   How does one survive, much less overcome, long...            10
# 1   I was only 10 when I saw this on TV but still ...            10
# 2
# 3   This is one of the most impressive movies I've...            10
# 4   I saw this film a few times, and loved Sally F...
# 5   What a moving, outstandingly brilliant film st...            10
# 6   Sybil, originally aired way before my time, bu...
# 7   I loved it for the time it was made it was mad...             8
# 8   This movie isn't actually about the actual cas...            10
# 9   This was a deeply harrowing movie to watch, an...             7
# 10
# 11  The 30th anniversary DVD edition of Sybil was ...            10
# 12  We have waited long enough!  After shelling ou...            10
# 13  This film made such an impact on me when i saw...            10
# 14
# 15  Looking for light entertainment? If you are, S...            10
# 16  I have D.I.D. Out of the many portrayals and i...             8
# 17  I think this was Sally Field's best acting mov...            10
# 18  This film was produced in the 70's when psychi...            10
# 19  A wonderful movie,one of Sally Fields best! Of...             9
# 20
# 21  Hi to you all, I have also seen this movie lon...
# 22  I remember being impressed with this movie whe...            10
# 23  Seamless and distinct Field portrays her chara...             9
# 24  This movie is ridiculously good! I watched it ...            10
# 25  It is one of the best movies made by director ...            10
# 26  Shutter Island. A film that will divide the fi...            10
# 27  There is one line of dialogue, right at the en...             9
# 28  Shutter Island is the story of Teddy Daniels, ...            10
# 29
# ..                                                ...           ...
# 45
# 46
# 47
# 48
# 49
# 50  A fantastic performance by the film's star, Ja...             8
# 51  This movie will keep you watching waiting for ...             8
# 52  I was surprised to see that this movie was rel...             8
# 53  What a remarkable film! The premise of the fil...            10
# 54
# 55  M.Night Shyamalan is one of those filmmakers t...             8
# 56  firstly, i have to compare this movie to La La...            10
# 57  Let me start off by saying that I haven't real...             8
# 58  A welcome return to form for the director and ...             9
# 59  When this film made it's first debut I was hes...             7
# 60  After watching this movie, I have to say, I do...             8
# 61  I will start off by saying this film was in no...             7
# 62
# 63  What a terrific comeback for Shyamalan! Many h...             8
# 64  Wow, this is my first review on IMDB. Let's st...            10
# 0   [How, does, one, survive, ,, much, less, overc...
# 1   [I, was, only, 10, when, I, saw, this, on, TV,...
# 2
# 3   [This, is, one, of, the, most, impressive, mov...
# 4   [I, saw, this, film, a, few, times, ,, and, lo...
# 5   [What, a, moving, ,, outstandingly, brilliant,...
# 6   [Sybil, ,, originally, aired, way, before, my,...
# 7   [I, loved, it, for, the, time, it, was, made, ...
# 8   [This, movie, is, n't, actually, about, the, a...
# 9   [This, was, a, deeply, harrowing, movie, to, w...
# 10
# 11  [The, 30th, anniversary, DVD, edition, of, Syb...
# 12  [We, have, waited, long, enough, !, After, she...
# 13  [This, film, made, such, an, impact, on, me, w...
# 14
# 15  [Looking, for, light, entertainment, ?, If, yo...
# 16  [I, have, D.I.D, ., Out, of, the, many, portra...
# 17  [I, think, this, was, Sally, Field, 's, best, ...
# 18  [This, film, was, produced, in, the, 70, 's, w...
# 19  [A, wonderful, movie, ,, one, of, Sally, Field...
# 20
# 21  [Hi, to, you, all, ,, I, have, also, seen, thi...
# 22  [I, remember, being, impressed, with, this, mo...
# 23  [Seamless, and, distinct, Field, portrays, her...
# 24  [This, movie, is, ridiculously, good, !, I, wa...
# 25  [It, is, one, of, the, best, movies, made, by,...
# 26  [Shutter, Island, ., A, film, that, will, divi...
# 27  [There, is, one, line, of, dialogue, ,, right,...
# 28  [Shutter, Island, is, the, story, of, Teddy, D...
# 29
# ..                                                ...
# 45
# 46
# 47
# 48
# 49
# 50  [A, fantastic, performance, by, the, film, 's,...
# 51  [This, movie, will, keep, you, watching, waiti...
# 52  [I, was, surprised, to, see, that, this, movie...
# 53  [What, a, remarkable, film, !, The, premise, o...
# 54
# 55  [M.Night, Shyamalan, is, one, of, those, filmm...
# 56  [firstly, ,, i, have, to, compare, this, movie...
# 57  [Let, me, start, off, by, saying, that, I, hav...
# 58  [A, welcome, return, to, form, for, the, direc...
# 59  [When, this, film, made, it, 's, first, debut,...
# 60  [After, watching, this, movie, ,, I, have, to,...
# 61  [I, will, start, off, by, saying, this, film, ...
# 62
# 63  [What, a, terrific, comeback, for, Shyamalan, ...
# 64  [Wow, ,, this, is, my, first, review, on, IMDB...
# 65  [The, only, reason, to, watch, this, movie, is...
# 66
# 67
# 68
# 69  [Shyamalan, 's, inconsistencies, as, a, direct...
# 70
# 71
# 72
# 73
# 74
#
#                                                tagged  \
# 0   [(How, WRB), (does, VBZ), (one, CD), (survive,...
# 1   [(I, PRP), (was, VBD), (only, RB), (10, CD), (...
# 2
# 3   [(This, DT), (is, VBZ), (one, CD), (of, IN), (...
# 4   [(I, PRP), (saw, VBD), (this, DT), (film, NN),...
# 5   [(What, WP), (a, DT), (moving, NN), (,, ,), (o...
# 6   [(Sybil, NNP), (,, ,), (originally, RB), (aire...
# 7   [(I, PRP), (loved, VBD), (it, PRP), (for, IN),...
# 8   [(This, DT), (movie, NN), (is, VBZ), (n't, RB)...
# 9   [(This, DT), (was, VBD), (a, DT), (deeply, RB)...
# 10
# 11  [(The, DT), (30th, JJ), (anniversary, JJ), (DV...
# 12  [(We, PRP), (have, VBP), (waited, VBN), (long,...
# 13  [(This, DT), (film, NN), (made, VBD), (such, P...
# 14
# 15  [(Looking, VBG), (for, IN), (light, JJ), (ente...
# 16  [(I, PRP), (have, VBP), (D.I.D, NNP), (., .), ...
# 17  [(I, PRP), (think, VBP), (this, DT), (was, VBD...
# 18  [(This, DT), (film, NN), (was, VBD), (produced...
# 19  [(A, DT), (wonderful, JJ), (movie, NN), (,, ,)...
# 20
# 21  [(Hi, NNP), (to, TO), (you, PRP), (all, DT), (...
# 22  [(I, PRP), (remember, VBP), (being, VBG), (imp...
# 23  [(Seamless, NN), (and, CC), (distinct, JJ), (F...
# 24  [(This, DT), (movie, NN), (is, VBZ), (ridiculo...
# 25  [(It, PRP), (is, VBZ), (one, CD), (of, IN), (t...
# 26  [(Shutter, NNP), (Island, NNP), (., .), (A, NN...
# 27  [(There, EX), (is, VBZ), (one, CD), (line, NN)...
# 28  [(Shutter, NNP), (Island, NNP), (is, VBZ), (th...
# 29
# ..                                                ...
# 45
# 46
# 47
# 48
# 49
# 50  [(A, DT), (fantastic, JJ), (performance, NN), ...
# 51  [(This, DT), (movie, NN), (will, MD), (keep, V...
# 52  [(I, PRP), (was, VBD), (surprised, VBN), (to, ...
# 53  [(What, WP), (a, DT), (remarkable, JJ), (film,...
# 54
# 55  [(M.Night, NNP), (Shyamalan, NNP), (is, VBZ), ...
# 56  [(firstly, RB), (,, ,), (i, NNS), (have, VBP),...
# 57  [(Let, VB), (me, PRP), (start, VB), (off, RP),...
# 58  [(A, DT), (welcome, JJ), (return, NN), (to, TO...
# 59  [(When, WRB), (this, DT), (film, NN), (made, V...
# 60  [(After, IN), (watching, VBG), (this, DT), (mo...
# 61  [(I, PRP), (will, MD), (start, VB), (off, RP),...
# 62
# 63  [(What, WP), (a, DT), (terrific, JJ), (comebac...
# 64  [(Wow, NNP), (,, ,), (this, DT), (is, VBZ), (m...
# 65  [(The, DT), (only, JJ), (reason, NN), (to, TO)...
# 66
# 67
# 68
# 69  [(Shyamalan, NNP), ('s, POS), (inconsistencies...
# 70
# 71
# 72
# 73
# 74
#
#                                               subtree
# 0   (NP survive/NN)(NP long-standing/JJ child/NN)(...
# 1   (NP TV/NN)(NP a/DT woman/NN)(NP a/DT child/NN)...
# 2
# 3   (NP acting/NN)(NP an/DT award/NN)(NP Ms./NNP)(...
# 4   (NP this/DT film/NN)(NP performance/NN)(NP a/D...
# 5   (NP a/DT moving/NN)(NP brilliant/JJ film/NN)(N...
# 6   (NP way/NN)(NP time/NN)(NP a/DT chance/NN)(NP ...
# 7   (NP the/DT time/NN)(NP sweet/NN)(NP emotion/NN...
# 8   (NP This/DT movie/NN)(NP the/DT actual/JJ case...
# 9   (NP harrowing/JJ movie/NN)(NP A/DT small/JJ ch...
# 10
# 11  (NP edition/NN)(NP July/NNP)(NP Sybil/NNP)(NP ...
# 12  (NP copy/NN)(NP this/DT movie/NN)(NP a/DT dema...
# 13  (NP This/DT film/NN)(NP an/DT impact/NN)(NP i/...
# 14
# 15  (NP light/JJ entertainment/NN)(NP a/DT remarka...
# 16  (NP D.I.D/NNP)(NP the/DT real/JJ thing/NN)(NP ...
# 17  (NP movie/NN)(NP a/DT story/NN)(NP the/DT psyc...
# 18  (NP This/DT film/NN)(NP psychiatry/NN)(NP ther...
# 19  (NP A/DT wonderful/JJ movie/NN)(NP coarse/NN)(...
# 20
# 21  (NP this/DT movie/NN)(NP the/DT book/NN)(NP vi...
# 22  (NP this/DT movie/NN)(NP TV/NN)(NP a/DT copy/N...
# 23  (NP a/DT true/JJ story/NN)(NP the/DT writer/NN...
# 24  (NP This/DT movie/NN)(NP high/JJ school/NN)(NP...
# 25  (NP the/DT best/JJS movies/NNS)(NP director/NN...
# 26  (NP A/NNP)(NP film/NN)(NP the/DT film/NN)(NP c...
# 27  (NP line/NN)(NP dialogue/NN)(NP the/DT end/NN)...
# 28  (NP the/DT story/NN)(NP A/NNP)(NP federal/JJ m...
# 29
# ..                                                ...
# 45
# 46
# 47
# 48
# 49
# 50  (NP A/DT fantastic/JJ performance/NN)(NP the/D...
# 51  (NP This/DT movie/NN)(NP the/DT next/JJ charac...
# 52  (NP this/DT movie/NN)(NP last/JJ year/NN)(NP c...
# 53  (NP a/DT remarkable/JJ film/NN)(NP The/DT prem...
# 54
# 55  (NP M.Night/NNP Shyamalan/NNP)(NP work/NN)(NP ...
# 56  (NP this/DT movie/NN)(NP material/NN)(NP Oscar...
# 57  (NP work/NN)(NP this/DT movie/NN)(NP vision/NN...
# 58  (NP A/DT welcome/JJ return/NN)(NP the/DT direc...
# 59  (NP this/DT film/NN)(NP first/JJ debut/NN)(NP ...
# 60  (NP this/DT movie/NN)(NP star/NN)(NP a/DT retu...
# 61  (NP this/DT film/NN)(NP no/DT way/NN)(NP perfe...
# 62
# 63  (NP a/DT terrific/JJ comeback/NN)(NP Many/NNP)...
# 64  (NP first/JJ review/NN)(NP the/DT movie/NN)(NP...
# 65  (NP The/DT only/JJ reason/NN)(NP this/DT movie...
# 66
# 67
# 68
# 69  (NP a/DT director/NN)(NP lady/NN)(NP Water/NNP...
# 70
# 71
# 72
# 73
# 74
#
# [75 rows x 8 columns]

# %%
output = tbl_imdb.groupby('Movie_Name').apply(lambda x: ','.join(x.subtree))

# %% [markdown]
# <font face="verdana">
# Summary:<br>
#
# For this home work i have picked 3 psychological dramas from IMDB:<br>
# <br> Sybil: https://www.imdb.com/title/tt0499260/
# <br> Split: https://www.imdb.com/title/tt4972582/
# <br> Shutter Island: https://www.imdb.com/title/tt1130884/
#
# Web scrapping IMDB User reviews:<br>
# 1. I used beautiful soup object to get the link for the movie.
# 2. I used another beautiful soup object to get to user reviews for each movies. The reviews were json object and was parsed to get review description and rating.
#
# Chunking:
# <br> 1.For NP chunking, I have defined a regular expression and parsed through each of the entities and collated all "NP" labled entities.
# <br> The output for this is the collated NP chunking for 3 movies as below.

# %%
output
# Out:
# Movie_Name
# Shutter Island    (NP the/DT best/JJS movies/NNS)(NP director/NN...
# split             (NP A/DT fantastic/JJ performance/NN)(NP the/D...
# sybil             (NP survive/NN)(NP long-standing/JJ child/NN)(...
NN)(NP tape/NN)(NP three-hour/JJ long/JJ drama/NN)(NP THIS/NNP)(NP version/NN),(NP TV/NN)(NP a/DT woman/NN)(NP a/DT child/NN)(NP mother/NN)(NP a/DT result/NN)(NP heart-breaking/NN)(NP the/DT psychologist/NN)(NP this/DT movie/NN),,(NP acting/NN)(NP an/DT award/NN)(NP Ms./NNP)(NP portrayal/NN)(NP this/DT poor/JJ girl/NN)(NP Sybil/NNP)(NP insight/NN)(NP the/DT part/NN)(NP role/NN)(NP the/DT psychiatrist/NN)(NP thru/NN)(NP memory/NN)(NP ordeal/NN)(NP abhorrent/NN)(NP upbringing/NN)(NP The/DT movie/NN)(NP thorough/JJ understanding/NN)(NP a/DT great/JJ movie/NN)(NP psychology/NN)(NP anyone/NN)(NP the/DT psychology/NN)(NP the/DT mind/NN)(NP trauma/NN)(NP this/DT movie/NN)(NP personal/JJ insight/NN)(NP own/JJ abusive/JJ upbringing/NN)(NP a/DT great/JJ film/NN)(NP entertainment/NN),(NP thi ...

# %% [markdown]
# <font face="verdana">
# #########################################################################################################################<br>
#
# # Homework 7<br>
# #########################################################################################################################<br>
#
# Cluster the reviews that you collected in homework 5, by doing the following:
# 1. In Python, select any one of the clustering methods covered in this course. Run it over the collection of reviews, and show at least two different ways of clustering the reviews, e.g., changing k in k-Means clustering or changing where you “cut” in Agnes or Diana.
# 2. Try to write a short phrase to characterize (give a natural interpretation of) what each cluster is generally centered on semantically. Is this hard to do in some cases? If so, make note of that fact.
# 3. Explain which of the two clustering results from question 1 is preferable (if one of them is), and why.
# Submit all of your inputs and outputs and your code for this assignment, along with a brief written explanation of your findings.

# %% [markdown]
# <font face="verdana">
# #########################################################################################################################<br>
# <br>
#
# ## NOTE: to adapt to Python 3, I have modified the code from the text book.
#
# #########################################################################################################################<br>
#
#
# ### AS Requested by Brook
#
# #########################################################################################################################<br>

# %%
import platform; 
print(platform.platform())
import sys; print("Python", sys.version)
import nltk; print( "nltk", nltk.__version__)
#from bs4 import BeautifulSoup, SoupStrainer
import requests; print ("requests", requests.__version__)

try :
    from urllib2 import Request, urlopen
except :
    from urllib.request import Request, urlopen

import re; 
print("re", re.__version__)

#from pattern3.en import parsetree
import os
print (os.environ['CONDA_DEFAULT_ENV'])
# Out:
# Windows-10-10.0.17134-SP0
# Python 3.6.1 |Anaconda custom (64-bit)| (default, May 11 2017, 13:25:24) [MSC v.1900 64 bit (AMD64)]
# nltk 3.2.3
# requests 2.14.2
# re 2.2.1
# base

# %% [markdown]
# <font face="verdana">
# #########################################################################################################################<br>
# <br>
# <br>
#
# ## All required definitions for normalization of corpus
#
# ## Code pulled from homework 6

# %%
# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = [] 
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
tbl_imdb.columns
# Out:
# Index(['Movie_Name', 'Review_Title', 'Review_Desc', 'Review_Rating',
#        'Review_url', 'word_token', 'tagged', 'subtree'],
#       dtype='object')

# %%
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
movie_titles = ""
synopses = ""
titles = ""

# %%
#synopses = tbl_imdb.groupby('Movie_Name').apply(lambda x: ','.join(x.Review_Desc))
movie_titles = tbl_imdb['Movie_Name'].tolist()
synopses = tbl_imdb['Review_Desc'].tolist()
titles= tbl_imdb['Review_Title'].tolist()

# %%
norm_movie_synopses = normalize_corpus(synopses,
                                       lemmatize=False)
norm_movie_synopses
# Out:
# ['survive much less overcome long standing child abuse newscasts littered unusual horrific stories children imprisoned closets chained beds little food water tiny children dying hot sweltering autos stuffed car trunks parent works yesterdays paper alone archbishop progressive church charged strangulation 15 year old girl sexually assaulted years opposite page woman boyfriend charged beating children metal pipe battered bodies bearing marks years abuse child happening somehow way must build sort mental toughness defense mechanism combat agony fear either tuning systematically shutting going deep states denial emotional withdrawal dorsett sally field unforgettable titular victim incessant child abuse woman dissolved sixteen separate distinct personalities order cope mother inflicted indescribable childhood tortures nothing short amazing especially dissociative scenes morphs lightning speed inner family combative self assertive peggy lou mothering suicidal mary vivacious ambitious vicky frightened thumb sucking ann even athletically inclined mike personalities created programmed unconsciously endure situation could handle triggered almost anything hostile argument piano music certain colors street sounds even word incredible fields performance real name ability tear barriers extent revert flood strange babblings shockingly infantile behavior drop hat compelling consuming feat scenes almost improvisatory style particular marvel scene sybils psychologist discovering patient artist nature lodged piano taken immature personalities tormented thunderous sounds dvorak beethoven illustrating torment paper brightly colored crayons director daniel petries credit able create safe environment field let like field emmy forever dispelled theories note actress trapped gidget like cuteness ironic bit casting joanne woodward essays role sybils psychologist dr cornelia wilbur finally pinpoints sybils mental disability starts long arduous journey putting selves together woodward academy award decades earlier similar victim mpd multiple personality disorder curious ultimately heavy handed dated faces eve woodward superb professional clearly element determined light end tunnel poor unfortunate girl late brad davis unsuspecting acquaintance wants know better adds tender sympathetic chapter sybils turbulent life william prince jane hoffman compelling sybils bloodless father stepmother offer puzzling ignorant explanations sybils problem charles lane significant scene sybils small town doctor child failed report examination findings little natasha ryan flashback sequences must commended reenacting harrowing details sybils childhood torment jessamine milner sybils grandmother affecting moments doting grandma offers brief moments respite however chilling portrait evil ever witness tv goes hands stocky harsh looking martine bartlett sybils monster mother lends horrifying believability fragmented unbalanced woman gets sadistic pleasure routine torturous acts bartlett respected stage actress little seen known another bizarre fascinating screen role crazy self abusing mental patient never promised rose garden hattie dorsett displays subtle calculating menace makes even terrifying devises number games inflict child scenes extremely repelling graphic nature handled responsibly possible considering actual incidents occur hopefully seeing dark disturbing ultimately important tv inspire read flora rheta schreibers best selling book details sybils childhood blackout episodes real woke finding missed entire sixth grade therapy sessions battle alter egos control subsequent unifying process professional vantage point dr wilbur depth trust able put never question boundaries consequences child abuse warning rent confusing chopped hour version available tape part hour long drama initially shown version rates 10',
#  '10 saw tv still remember scenes vividly believe since sally field awesome portrays woman abused child mother developed multiple personalities result fascinating heart breaking psychologist played joanne woodward good uncovers personalities reveals suppressed memories caused recommend enough 10 10',
#  '',
#  'wow first review imdb let us start got interested split remember 13 years old sitting couch nights halloween wanted watch horror browsed free section xfinity demand scrolled page eyes everted split read plot synopsis really liked concept watching first time best watching experiences ever glued seat whole time watching genuinely scared noticed builds suspense paid attention interesting camera angles cinematographer chose shot watching excited watch night shyamalan films eventually built love james mcavoy oscar worthy performance playing 23 different personalities anya taylor joy good performance played interesting character techniques building showing suspense masterful cinematography golden story investing twist turns fun first understand twist ending browsing internet found involved character unbreakable watching treat 14 years old right passion live split favorite films time always love',
#  'reason watch enjoy amazing performance james mcavoy able effectively convincingly portray wildly different characters almost effortlessly minimal change physical appearance entirely superb acting scene particular cycling completely different personalities character drop hat quite remarkable twist end disappointing almost non existent unbreakable even understand twist least keep entertained atrociously paced night shymalans',
#  '',
#  '',
#  '',
#  'shyamalans inconsistencies director decidedly ignominious spellbound us sixth sense soon befuddled lady water provoked derisive jeers happening merely bored us last airbender earth pared horror visit signalled renaissance auteur genuinely frightening aesthetic even decent shyamalan twist armed seems significant budget far loopy creative ambition split shyamalans true calling card hopefully far fortuitous run features using disorder true story create bonkers premise mcavoy plays kevin man possesses 23 distinct personalities male female young old homosexual heterosexual ocd require insulin diabetes really rather volatile dangerous catch 24th arrive hell set break loose sounds like actors dream job right opportunity flex acting muscles nth degree accent changing mannerism altering mcavoy rises challenge performance breathtaking versatility around never quite reliable towering performance however plot functions incredibly tense kidnapping hostage situation doctor purports expert eventually serving narrative purpose early scenes shyamalans switching doctors narrative grinds something halt leaving longing far interesting story develop ultimately resolve said never bores second thanks shyamalans distinctive style ominous score well anya taylor joy impressive witch proves trick pony addition like visit split unexpectedly quite funny way never sacrifices tension rather serves enhance catching guard scares recovering bizarre joke terrific tactic serves well worthy recommendation films third act evolves something genuinely terrifying ferociously tense twist upon twist piles create thrilling sense chaos dread less convincing shyamalans repeated attempts motifs beasts animals feel shoehorned unnecessary despite al split worthy work shyamalan deliver jolt high octane thrills nerves certainly needed doldrums january dumping ground films',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
import pandas as pd

reviews = {'synopses': synopses, 'cluster': clusters}

frame = pd.DataFrame(reviews, index = [clusters] , columns = ['synopses', 'cluster'])

# %%
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
import re
import nltk
import string
from nltk.stem import WordNetLemmatizer
from html.parser import HTMLParser
import unicodedata

stopword_list = nltk.corpus.stopwords.words('english')
stopword_list = stopword_list + ['mr', 'mrs', 'come', 'go', 'get',
                                 'tell', 'listen', 'one', 'two', 'three',
                                 'four', 'five', 'six', 'seven', 'eight',
                                 'nine', 'zero', 'join', 'find', 'make',
                                 'say', 'ask', 'tell', 'see', 'try', 'back',
                                 'also', 'sybil', 'movies','movie','watched','film']
wnl = WordNetLemmatizer()
html_parser = HTMLParser()

def tokenize_text(text):
    tokens = nltk.word_tokenize(text) 
    tokens = [token.strip() for token in tokens]
    return tokens

def expand_contractions(text, contraction_mapping):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text
    
    
#from pattern3.en import tag
from nltk.corpus import wordnet as wn

# Annotate text tokens with POS tags
def pos_tag_text(text):
    
    def penn_to_wn_tags(pos_tag):
        if pos_tag.startswith('J'):
            return wn.ADJ
        elif pos_tag.startswith('V'):
            return wn.VERB
        elif pos_tag.startswith('N'):
            return wn.NOUN
        elif pos_tag.startswith('R'):
            return wn.ADV
        else:
            return None
    
    tagged_text = nltk.pos_tag(text)
    tagged_lower_text = [(word.lower(), penn_to_wn_tags(pos_tag))
                         for word, pos_tag in
                         tagged_text]
    return tagged_lower_text
    
# lemmatize text based on POS tags    
def lemmatize_text(text):
    
    pos_tagged_text = pos_tag_text(text)
    lemmatized_tokens = [wnl.lemmatize(word, pos_tag) if pos_tag
                         else word                     
                         for word, pos_tag in pos_tagged_text]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text
    

def remove_special_characters(text):
    tokens = tokenize_text(text)
    pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
    filtered_tokens = filter(None, [pattern.sub(' ', token) for token in tokens])
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text
    
    
def remove_stopwords(text):
    tokens = tokenize_text(text)
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

def keep_text_characters(text):
    filtered_tokens = []
    tokens = tokenize_text(text)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

def unescape_html(parser, text):
    
    return parser.unescape(text)

def normalize_corpus(corpus, lemmatize=True, 
                     only_text_chars=False,
                     tokenize=False):
    
    normalized_corpus = []    
    for text in corpus:
        text = html_parser.unescape(text)
        text = expand_contractions(text, CONTRACTION_MAP)
        if lemmatize:
            text = lemmatize_text(text)
        else:
            text = text.lower()
        text = remove_special_characters(text)
        text = remove_stopwords(text)
        if only_text_chars:
            text = keep_text_characters(text)
        
        if tokenize:
            text = tokenize_text(text)
            normalized_corpus.append(text)
        else:
            normalized_corpus.append(text)
            
    return normalized_corpus


def parse_document(document):
    document = re.sub('\n', ' ', document)
    if isinstance(document, str):
        document = document
    elif isinstance(document, unicode):
        return unicodedata.normalize('NFKD', document).encode('ascii', 'ignore')
    else:
        raise ValueError('Document is not string or unicode!')
    document = document.strip()
    sentences = nltk.sent_tokenize(document)
    sentences = [sentence.strip() for sentence in sentences]
    return sentences

# %%
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# ... ref : Text Analytics with Python, Sarker, p. 270
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def build_feature_matrix(documents, feature_type = 'frequency',
                         ngram_range = (1, 1), min_df = 0.0, max_df = 1.0):

    feature_type = feature_type.lower().strip()  
    
    if feature_type == 'binary':
        vectorizer = CountVectorizer(binary = True, min_df = min_df,
                                     max_df = max_df, ngram_range = ngram_range)
    elif feature_type == 'frequency':
        vectorizer = CountVectorizer(binary = False, min_df = min_df,
                                     max_df = max_df, ngram_range = ngram_range)
    elif feature_type == 'tfidf':
        vectorizer = TfidfVectorizer(min_df = min_df, max_df = max_df, 
                                     ngram_range = ngram_range)
    else:
        raise Exception("Wrong feature type entered. Possible values: 'binary', 'frequency', 'tfidf'")

    feature_matrix = vectorizer.fit_transform(documents).astype(float)
    
    return vectorizer, feature_matrix

# %%
def print_cluster_data(cluster_data):
    # print cluster details
    for cluster_num, cluster_details in cluster_data.items():
        print( 'Cluster {} details:'.format(cluster_num))
        print( '-'*20)
        print( 'Key features:', cluster_details['key_features'])
        print( 'Movies in this cluster:')
        print( ', '.join(cluster_details['movies']))
        print( '='*40)

# %% [markdown]
# <font face="verdana">
# #########################################################################################################################<br>
# <br>
# <br>
#
# ## Homework 8
#
# <br>
# <br>
#
#
#
# Perform a vocabulary-based sentiment analysis of the movie reviews you used in homework 5 and homework 7, by doing the following:
# 1.	In Python, load one of the sentiment vocabularies referenced in the textbook, and run the sentiment analyzer as explained in the corresponding reference. Add words to the sentiment vocabulary, if you think you need to, to better fit your particular text collection.
#
# 2.	For each of the clusters you created in homework 7, compute the average, median, high, and low sentiment scores for each cluster. Explain whether you think this reveals anything interesting about the clusters.
#
# 3.	For extra credit, analyze sentiment of chunks as follows:
# a.	Take the chunks from homework 5, and in Python, run each chunk individually through your sentiment analyzer that you used in question 1. If the chunk registers a nonneutral sentiment, save it in a tabular format (the chunk, the sentiment score).
# b.	Now sort the table twice, once to show the highest negative-sentiment-scoring chunks at the top and again to show the highest positive-sentiment-scoring chunks at the top. Examine the upper portions of both sorted lists, to identify any trends, and explain what you see.
# Submit all of your inputs and outputs and your code for this assignment, along with a brief written explanation of your findings.
# #########################################################################################################################<br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# STEPS:
#
# .1. Table is created to capture cluster, cluster words, positive score, negative score <br>
# .2. Movie reviews are passed to tdidf vector matrix and Kmeans 3 clusters are created <br>
# .3. Each words in the cluster are lemmantized, pos tagged and sentiment scores are obtained and tabulated <br>
# .4. Results and observations are in Summary

# %%
tbl_cluster  = pd.DataFrame(columns = [
    'Cluster#',
    'top_word_1',
    'top_word_2',
    'top_word_3',
    'top_word_4',
    'top_word_5',
    'pos_score_word_1',
    'neg_score_word_1',
    'pos_score_word_2',
    'neg_score_word_2',
    'pos_score_word_3',
    'neg_score_word_3',
    'pos_score_word_4',
    'neg_score_word_4',
    'pos_score_word_5',
    'neg_score_word_5'])

i_index=[]
i_index = 0

# %%
# Annotate text tokens with POS tags
#n - NOUN 
#v - VERB 
#a - ADJECTIVE 
#s - ADJECTIVE SATELLITE 
#r - ADVERB 
def getLemma(word):
    return WordNetLemmatizer().lemmatize(word)

def pos_tag_word(word):
    #lword = WordNetLemmatizer().lemmatize(word) 
    #print(word) #,": ",lword)
    pos_tag = nltk.pos_tag(word)
    print(word, "is an ", pos_tag[0][1])
    if 'NN' in pos_tag[0][1] or 'NNS' in pos_tag[0][1]:
        return 'n' 
    elif pos_tag[0][1] == 'VB' or pos_tag[0][1] == 'VBN': 
        return 'v'
    elif pos_tag[0][1] == 'JJ': #ADJECTIVE
        return 'a'
    elif pos_tag[0][1] == 'RB':
        return 'r'
    else:
        return 'n'

# %%
def tokenize_and_lemme(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            #token = WordNetLemmatizer().lemmatize(token)
            filtered_tokens.append(token)
    lemme = [ WordNetLemmatizer().lemmatize(t) for t in filtered_tokens]
    return lemme

# %%
#lemme_movie_synopses = tokenize_and_lemme(norm_movie_synopses)
norm_movie_synopses
# Out:
# ['survive much less overcome long standing child abuse newscasts littered unusual horrific stories children imprisoned closets chained beds little food water tiny children dying hot sweltering autos stuffed car trunks parent works yesterdays paper alone archbishop progressive church charged strangulation 15 year old girl sexually assaulted years opposite page woman boyfriend charged beating children metal pipe battered bodies bearing marks years abuse child happening somehow way must build sort mental toughness defense mechanism combat agony fear either tuning systematically shutting going deep states denial emotional withdrawal dorsett sally field unforgettable titular victim incessant child abuse woman dissolved sixteen separate distinct personalities order cope mother inflicted indescribable childhood tortures nothing short amazing especially dissociative scenes morphs lightning speed inner family combative self assertive peggy lou mothering suicidal mary vivacious ambitious vicky frightened thumb sucking ann even athletically inclined mike personalities created programmed unconsciously endure situation could handle triggered almost anything hostile argument piano music certain colors street sounds even word incredible fields performance real name ability tear barriers extent revert flood strange babblings shockingly infantile behavior drop hat compelling consuming feat scenes almost improvisatory style particular marvel scene sybils psychologist discovering patient artist nature lodged piano taken immature personalities tormented thunderous sounds dvorak beethoven illustrating torment paper brightly colored crayons director daniel petries credit able create safe environment field let like field emmy forever dispelled theories note actress trapped gidget like cuteness ironic bit casting joanne woodward essays role sybils psychologist dr cornelia wilbur finally pinpoints sybils mental disability starts long arduous journey putting selves together woodward academy award decades earlier similar victim mpd multiple personality disorder curious ultimately heavy handed dated faces eve woodward superb professional clearly element determined light end tunnel poor unfortunate girl late brad davis unsuspecting acquaintance wants know better adds tender sympathetic chapter sybils turbulent life william prince jane hoffman compelling sybils bloodless father stepmother off

#  '',
#  '',
#  '',
#  '',
#  '']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from __future__ import print_function
from nltk.corpus import sentiwordnet as swn

#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=1.8, 
                                   max_features=200000,
                                   min_df=0.2, 
                                   stop_words='english',
                                    use_idf=True, 
                                   tokenizer=tokenize_and_lemme)

#%time 
tfidf_matrix = tfidf_vectorizer.fit_transform(norm_movie_synopses) #fit the vectorizer to synopses

#print(tfidf_matrix.shape)

num_clusters = 3

km = KMeans(n_clusters=num_clusters)

#%time 
km.fit(tfidf_matrix)

clusters = km.labels_.tolist()


totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synopses:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)
    
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
terms = tfidf_vectorizer.get_feature_names()
print(vocab_frame)    
    
print("Top terms per cluster:")
print()
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
for i in range(num_clusters):
    #print("Cluster %d words:" % i, end='')
    print("Cluster %d words:\n" % i)
    print("-----------------------------")
    
    top_word = ""
    for ind in order_centroids[i, :6]:
        #print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
        print(vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0])
        top_word = top_word + "," + vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0]
        
         # print(vocab_frame.ix[terms[2].split(' ')].values.tolist()[0][0])
       # print(vocab_frame.ix[terms[3].split(' ')].values.tolist()[0][0])
       # print(vocab_frame.ix[terms[4].split(' ')].values.tolist()[0][0])
       # print(vocab_frame.ix[terms[5].split(' ')].values.tolist()[0][0])
       # print(vocab_frame.ix[terms[6].split(' ')].values.tolist()[0][0])
    #print("\ntop_words \n",top_word)
    #print(pos_tag_word([top_word.split(',')[1]]))
    word1 = getLemma(top_word.split(',')[1])
    #top_word_1 = top_word.split(',')[1] + '.' + pos_tag_word([])+'.01'
    top_word_1 = word1 + '.' + pos_tag_word([word1])+'.01'
    word2 = getLemma(top_word.split(',')[2])
    top_word_2 = word2 + '.' + pos_tag_word([word2])+'.01'
    
    word3 = getLemma(top_word.split(',')[3])
    top_word_3 = word3 + '.' + pos_tag_word([word3])+'.01'
    
    word4 = getLemma(top_word.split(',')[4])
    top_word_4 = word4  + '.' + pos_tag_word([word4])+'.01'
    
    word5 = getLemma(top_word.split(',')[5])
    top_word_5 = word5  + '.' + pos_tag_word([word5])+'.01'
    
    print(word1)
    try:
        top_word_1_p = (swn.senti_synset(top_word_1)).pos_score()
        top_word_1_n = (swn.senti_synset(top_word_1)).neg_score()
    
    except:
        print("Exception")
        top_word_1_p = 0.0
        top_word_1_n = 0.0
        
    try:
        top_word_2_p = (swn.senti_synset(top_word_2)).pos_score()
        top_word_2_n = (swn.senti_synset(top_word_2)).neg_score()
    
    except:
        top_word_2_p = 0.0
        top_word_2_n = 0.0
      
    try:
        top_word_3_p = (swn.senti_synset(top_word_3)).pos_score()
        top_word_3_n = (swn.senti_synset(top_word_3)).neg_score()
    except:
        top_word_3_p = 0.0
        top_word_3_n = 0.0
        
    try:
        top_word_4_p = (swn.senti_synset(top_word_4)).pos_score()
        top_word_4_n = (swn.senti_synset(top_word_4)).neg_score()
    except:
        top_word_4_p = 0.0
        top_word_4_n = 0.0
    try:
        top_word_5_p = (swn.senti_synset(top_word_5)).pos_score()
        top_word_5_n = (swn.senti_synset(top_word_5)).neg_score()
    except:
        top_word_5_p = 0.0
        top_word_5_n = 0.0  
        
    raw_data = {'Cluster#':i,
                'top_word_1':top_word_1,
                'top_word_2':top_word_2,
                'top_word_3':top_word_3,
                'top_word_4':top_word_4,
                'top_word_5':top_word_5,
                'pos_score_word_1':float(top_word_1_p),
                'neg_score_word_1':float(top_word_1_n),
                'pos_score_word_2':float(top_word_2_p),
                'neg_score_word_2':float(top_word_2_n),
                'pos_score_word_3':float(top_word_3_p),
                'neg_score_word_3':float(top_word_3_n),
                'pos_score_word_4':float(top_word_4_p),
                'neg_score_word_4':float(top_word_4_n),
                'pos_score_word_5':float(top_word_5_p),
                'neg_score_word_5':float(top_word_5_n)               
               }
    df_tbl = pd.DataFrame(raw_data,
            columns = [
                        'Cluster#',
                        'top_word_1',
                        'top_word_2',
                        'top_word_3',
                        'top_word_4',
                        'top_word_5',
                        'pos_score_word_1',
                        'neg_score_word_1',
                        'pos_score_word_2',
                        'neg_score_word_2',
                        'pos_score_word_3',
                        'neg_score_word_3',
                        'pos_score_word_4',
                        'neg_score_word_4',
                        'pos_score_word_5',
                        'neg_score_word_5'], index = [i_index + 1])
    tbl_cluster = tbl_cluster.append(df_tbl)
    print("raw_data ",raw_data)
# Out:
#                     words
# how                   how
# doe                  does
# one                   one
# surviv            survive
# much                 much
# less                 less
# overcom          overcome
# long-stand  long-standing
# child               child
# abus                abuse
# newscast        newscasts
# are                   are
# litter           littered
# with                 with
# the                   the
# more                 more
# unusu             unusual
# horrif           horrific
# stori             stories
# children         children
# imprison       imprisoned
# in                     in
# closet            closets
# or                     or
# chain             chained
# to                     to
# bed                  beds
# with                 with
# littl              little
# more                 more
# ...                   ...
# from                 from
# shyamalan       shyamalan
# that                 that
# will                 will
# deliv             deliver
# a                       a
# jolt                 jolt
# of                     of
# high                 high
# octan              octane
# thrill            thrills
# to                     to
# your                 your
# nerv               nerves
# one                   one
# which               which
# will                 will
# certain         certainly
# be                     be
# need               needed
# in                     in
# the                   the
# doldrum          doldrums
# of                     of
# the                   the
# januari           january
# dump              dumping
# ground             ground
# of                     of
# film                films
#
# [12835 rows x 1 columns]
# Top terms per cluster:
#
# Cluster 0 words:
#
# -----------------------------
# times
# many
# way
# watched
# thriller
# stories
# ['time'] is an  NN
# ['many'] is an  JJ
# ['way'] is an  NN
# ['watched'] is an  VBN
# ['thriller'] is an  NN
# time
# raw_data  {'Cluster#': 0, 'top_word_1': 'time.n.01', 'top_word_2': 'many.a.01', 'top_word_3': 'way.n.01', 'top_word_4': 'watched.v.01', 'top_word_5': 'thriller.n.01', 'pos_score_word_1': 0.0, 'neg_score_word_1': 0.0, 'pos_score_word_2': 0.0, 'neg_score_word_2': 0.0, 'pos_score_word_3': 0.0, 'neg_score_word_3': 0.0, 'pos_score_word_4': 0.0, 'neg_score_word_4': 0.0, 'pos_score_word_5': 0.0, 'neg_score_word_5': 0.0}
# Cluster 1 words:
#
# -----------------------------
# like
# great
# thriller
# stories
# performance
# character
# ['like'] is an  IN
# ['great'] is an  JJ
# ['thriller'] is an  NN
# ['story'] is an  NN
# ['performance'] is an  NN
# like
# raw_data  {'Cluster#': 1, 'top_word_1': 'like.n.01', 'top_word_2': 'great.a.01', 'top_word_3': 'thriller.n.01', 'top_word_4': 'story.n.01', 'top_word_5': 'performance.n.01', 'pos_score_word_1': 0.125, 'neg_score_word_1': 0.0, 'pos_score_word_2': 0.0, 'neg_score_word_2': 0.0, 'pos_score_word_3': 0.0, 'neg_score_word_3': 0.0, 'pos_score_word_4': 0.0, 'neg_score_word_4': 0.0, 'pos_score_word_5': 0.125, 'neg_score_word_5': 0.0}
# Cluster 2 words:
#
# -----------------------------
# personalities
# watched
# performance
# character
# times
# way
# ['personality'] is an  NN
# ['watched'] is an  VBN
# ['performance'] is an  NN
# ['character'] is an  NN
# ['time'] is an  NN
# personality
# raw_data  {'Cluster#': 2, 'top_word_1': 'personality.n.01', 'top_word_2': 'watched.v.01', 'top_word_3': 'performance.n.01', 'top_word_4': 'character.n.01', 'top_word_5': 'time.n.01', 'pos_score_word_1': 0.0, 'neg_score_word_1': 0.125, 'pos_score_word_2': 0.0, 'neg_score_word_2': 0.0, 'pos_score_word_3': 0.125, 'neg_score_word_3': 0.0, 'pos_score_word_4': 0.0, 'neg_score_word_4': 0.0, 'pos_score_word_5': 0.0, 'neg_score_word_5': 0.0}

# %% [markdown]
# <font face="verdana">
#
# ## Table summary

# %%
tbl_cluster.reset_index(drop= True, inplace=True)
tbl_cluster
# Out:
#   Cluster#        top_word_1    top_word_2        top_word_3      top_word_4  \
# 0        0         time.n.01     many.a.01          way.n.01    watched.v.01
# 1        1         like.n.01    great.a.01     thriller.n.01      story.n.01
# 2        2  personality.n.01  watched.v.01  performance.n.01  character.n.01
#
#          top_word_5  pos_score_word_1  neg_score_word_1  pos_score_word_2  \
# 0     thriller.n.01             0.000             0.000               0.0
# 1  performance.n.01             0.125             0.000               0.0
# 2         time.n.01             0.000             0.125               0.0
#
#    neg_score_word_2  pos_score_word_3  neg_score_word_3  pos_score_word_4  \
# 0               0.0             0.000               0.0               0.0
# 1               0.0             0.000               0.0               0.0
# 2               0.0             0.125               0.0               0.0
#
#    neg_score_word_4  pos_score_word_5  neg_score_word_5
# 0               0.0             0.000               0.0
# 1               0.0             0.125               0.0
# 2               0.0             0.000               0.0
