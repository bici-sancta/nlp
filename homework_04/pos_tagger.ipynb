# %%
#
# ... file : pos_tagger.py
#
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# ...
# ... msds 7337 NLP
# ... homework 04
# ... part of speech tagging
# ... pmcdevitt@smu.edu
# ... 10-oct-2018
# ...
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-

# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# ... load packages
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import os
import re
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import PlaintextCorpusReader
from nltk.probability import ConditionalFreqDist

from pattern.en import tag


get_ipython().magic('matplotlib inline')
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.rc('xtick', labelsize=20)     
plt.rc('ytick', labelsize=20)

# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# ... some directory and file name definitions
# ... -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-

home_dir = "/home/mcdevitt/_ds/_smu/_src/nlp/homework_04/"
corpus_root = "./text/"
plot_dir = "./plots/"
files = ".*\.txt"

os.chdir(home_dir)
os.chdir(corpus_root)

penn_pos = pd.read_csv("penn_treebank.csv")


file = open("two_sentences.txt", "r")
for line in file :
    
    print (line)
    
    tokens = nltk.word_tokenize(line)

# ... nltk pos tagger

    tag_nltk = nltk.pos_tag(tokens)

    df_tag_nltk = pd.DataFrame(tag_nltk, columns = ['word', 'pos'])
    df_dscr_nltk = pd.merge(df_tag_nltk, penn_pos, on='pos', how='left')
    df_dscr_nltk.columns = ['word', 'pos_nltk', 'descr_nltk']
    
# ... pattern pos tagger

    tag_ptrn = tag(line)
    
    df_tag_ptrn = pd.DataFrame(tag_ptrn, columns = ['word', 'pos'])
    df_dscr_ptrn = pd.merge(df_tag_ptrn, penn_pos, on = 'pos', how = 'left')
    df_dscr_ptrn.columns = ['word', 'pos_pattern', 'descr_pattern']
    
    df_tag_all = pd.concat([df_dscr_nltk, df_dscr_ptrn], axis = 1)
    df_tag_all
# Out:
# The power of numbers is never more evident than when we use them to speculate on the time of our dying.
#          word pos_nltk                                descr_nltk       word  \
# 0         The       DT                                Determiner        The
# 1       power       NN                    Noun, singular or mass      power
# 2          of       IN  Preposition or subordinating conjunction         of
# 3     numbers      NNS                              Noun, plural    numbers
# 4          is      VBZ         Verb, 3rd person singular present         is
# 5       never       RB                                    Adverb      never
# 6        more      RBR                       Adverb, comparative       more
# 7     evident       JJ                                 Adjective    evident
# 8        than       IN  Preposition or subordinating conjunction       than
# 9        when      WRB                                 Wh-adverb       when
# 10         we      PRP                          Personal pronoun         we
# 11        use      VBP     Verb, non-3rd person singular present        use
# 12       them      PRP                          Personal pronoun       them
# 13         to       TO                                        to         to
# 14  speculate       VB                           Verb, base form  speculate
# 15         on       IN  Preposition or subordinating conjunction         on
# 16        the       DT                                Determiner        the
# 17       time       NN                    Noun, singular or mass       time
# 18         of       IN  Preposition or subordinating conjunction         of
# 19        our     PRP$                        Possessive pronoun        our
# 20      dying       NN                    Noun, singular or mass      dying
# 21          .        .                                       NaN          .
#
#    pos_pattern                             descr_pattern
# 0           DT                                Determiner
# 1           NN                    Noun, singular or mass
# 2           IN  Preposition or subordinating conjunction
# 3          NNS                              Noun, plural
# 4          VBZ         Verb, 3rd person singular present
# 5           RB                                    Adverb
# 6          RBR                       Adverb, comparative
# 7           JJ                                 Adjective
# 8           IN  Preposition or subordinating conjunction
# 9          WRB                                 Wh-adverb
# 10         PRP                          Personal pronoun
# 11         VBP     Verb, non-3rd person singular present
# 12         PRP                          Personal pronoun
# 13          TO                                        to
# 14          VB                           Verb, base form
# 15          IN  Preposition or subordinating conjunction
# 16          DT                                Determiner
# 17          NN                    Noun, singular or mass
# 18          IN  Preposition or subordinating conjunction
# 19        PRP$                        Possessive pronoun
# 20         VBG        Verb, gerund or present participle
# 21           .                                       NaN
# I was cured all right.
#     word pos_nltk              descr_nltk   word pos_pattern  \
# 0      I      PRP        Personal pronoun      I         PRP
# 1    was      VBD        Verb, past tense    was         VBD
# 2  cured      VBN   Verb, past participle  cured         VBN
# 3    all       DT              Determiner    all          DT
# 4  right       NN  Noun, singular or mass  right          RB
# 5      .        .                     NaN      .           .
#
#            descr_pattern
# 0       Personal pronoun
# 1       Verb, past tense
# 2  Verb, past participle
# 3             Determiner
# 4                 Adverb
# 5                    NaN
# His Republican opponent, the incumbent Bruce Rauner, has made much of the toilet issue in the final months of the gubernatorial campaign, running an ad calling Pritzker "the porcelain prince of tax avoidance."
#              word pos_nltk                                descr_nltk  \
# 0             His     PRP$                        Possessive pronoun
# 1      Republican       JJ                                 Adjective
# 2        opponent       NN                    Noun, singular or mass
# 3               ,        ,                                       NaN
# 4             the       DT                                Determiner
# 5       incumbent       JJ                                 Adjective
# 6           Bruce      NNP                     Proper noun, singular
# 7          Rauner      NNP                     Proper noun, singular
# 8               ,        ,                                       NaN
# 9             has      VBZ         Verb, 3rd person singular present
# 10           made      VBN                     Verb, past participle
# 11           much       RB                                    Adverb
# 12             of       IN  Preposition or subordinating conjunction
# 13            the       DT                                Determiner
# 14         toilet       NN                    Noun, singular or mass
# 15          issue       NN                    Noun, singular or mass
# 16             in       IN  Preposition or subordinating conjunction
# 17            the       DT                                Determiner
# 18          final       JJ                                 Adjective
# 19         months      NNS                              Noun, plural
# 20             of       IN  Preposition or subordinating conjunction
# 21            the       DT                                Determiner
# 22  gubernatorial       JJ                                 Adjective
# 23       campaign       NN                    Noun, singular or mass
# 24              ,        ,                                       NaN
# 25        running      VBG        Verb, gerund or present participle
# 26             an       DT                                Determiner
# 27             ad       NN                    Noun, singular or mass
# 28        calling      VBG        Verb, gerund or present participle
# 29       Pritzker      NNP                     Proper noun, singular
# 30             ``       ``                                       NaN
# 31            the       DT                                Determiner
# 32      porcelain       NN                    Noun, singular or mass
# 33         prince       NN                    Noun, singular or mass
# 34             of       IN  Preposition or subordinating conjunction
# 35            tax       NN                    Noun, singular or mass
# 36      avoidance       NN                    Noun, singular or mass
# 37              .        .                                       NaN
# 38             ''       ''                                       NaN
#
#              word pos_pattern                             descr_pattern
# 0             His        PRP$                        Possessive pronoun
# 1      Republican          JJ                                 Adjective
# 2        opponent          NN                    Noun, singular or mass
# 3               ,           ,                                       NaN
# 4             the          DT                                Determiner
# 5       incumbent          JJ                                 Adjective
# 6           Bruce         NNP                     Proper noun, singular
# 7          Rauner         NNP                     Proper noun, singular
# 8               ,           ,                                       NaN
# 9             has         VBZ         Verb, 3rd person singular present
# 10           made         VBN                     Verb, past participle
# 11           much          JJ                                 Adjective
# 12             of          IN  Preposition or subordinating conjunction
# 13            the          DT                                Determiner
# 14         toilet          NN                    Noun, singular or mass
# 15          issue          NN                    Noun, singular or mass
# 16             in          IN  Preposition or subordinating conjunction
# 17            the          DT                                Determiner
# 18          final          JJ                                 Adjective
# 19         months         NNS                              Noun, plural
# 20             of          IN  Preposition or subordinating conjunction
# 21            the          DT                                Determiner
# 22  gubernatorial          JJ                                 Adjective
# 23       campaign          NN                    Noun, singular or mass
# 24              ,           ,                                       NaN
# 25        running         VBG        Verb, gerund or present participle
# 26             an          DT                                Determiner
# 27             ad          NN                    Noun, singular or mass
# 28        calling         VBG        Verb, gerund or present participle
# 29       Pritzker         NNP                     Proper noun, singular
# 30              "           "                                       NaN
# 31            the          DT                                Determiner
# 32      porcelain          NN                    Noun, singular or mass
# 33         prince          NN                    Noun, singular or mass
# 34             of          IN  Preposition or subordinating conjunction
# 35            tax          NN                    Noun, singular or mass
# 36      avoidance          NN                    Noun, singular or mass
# 37              .           .                                       NaN
# 38              "           "                                       NaN
