# %%
# !pip install imdb
# Out:
# Collecting imdb
#   Could not find a version that satisfies the requirement imdb (from versions: )
# No matching distribution found for imdb

# %%
import pandas as pd
import imdb
from bs4 import BeautifulSoup
import requests
import re
import json

my_movies = ["The Big Lebowski","Fargo"]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-48af2867737b> in <module>()
#       1 import pandas as pd
# ----> 2 import imdb
#       3 from bs4 import BeautifulSoup
#       4 import requests
#       5 import re
#
# ImportError: No module named 'imdb'

# %%
tbl_imdb  = pd.DataFrame(columns = [
    'Movie_Name',
    'Review_Title',
    'Review_Desc',
    'Review_url'])

i_index=[]
i_index = 0

# %%
for movie_name in my_movies:
    
    print(movie_name)
    
    ia = imdb.IMDb()
    results = ia.search_movie(movie_name)
    mv = results[0] #First result
    url = ia.get_imdbURL(mv) #URL for first result
    user_review_url = url+'reviews/'
    response = requests.get(user_review_url)
    
    soup = BeautifulSoup(response.text, 'lxml')
    
    try:
#        print("+++================== Begin Soup =================================+++\n")
#        print(soup)
#        print("+++================== End Soup =================================+++\n")

        movies = soup.select('a.title')
 #       print("+++================== Begin Movies =================================+++\n")
 #       print("movies", movies)
 #       print("+++================== End Movies =================================+++\n")

        links = [a.attrs.get('href') for a in soup.select('a.title')]
        
 #       print(links)
        # Store each item into dictionary (data), then put those into a list (imdb)
        
        for index in range(0, len(movies)):
            
            # Separate movie into: 'place', 'title', 'year'
            
            review_title = movies[index].get_text()
            
#            review_desc = ""
            
#            print(index, " ", review_title)
            
            raw_data = {'Movie_Name' : movie_name,
                    'Review_Title' : review_title,
                    'Review_Desc' : review_desc,
                    'Review_url': links[index] }
            
            df_tbl = pd.DataFrame(raw_data,
                        columns = [
                        'Movie_Name',
                        'Review_Title',
                        'Review_Desc',
                        'Review_url'], index = [i_index + 1])
            
            tbl_imdb = tbl_imdb.append(df_tbl)
            
    except Exception as e:
        print('Error : ' + str(e))
# Out:
# The Big Lebowski
# Error : name 'review_desc' is not defined
# Fargo
# Error : name 'review_desc' is not defined

# %%
tbl_imdb
# Out:
#          Movie_Name                                       Review_Title  \
# 1  The Big Lebowski   The film with the highest rewatchability fact...
# 1  The Big Lebowski   You can watch it a million times, and yet, it...
# 1  The Big Lebowski                                 Simply Beautiful\n
# 1  The Big Lebowski   My favourite Coen brothers movie and one of t...
# 1  The Big Lebowski               The Most Quotable Film of All Time\n
# 1  The Big Lebowski                        Greatest movie ever made.\n
# 1  The Big Lebowski                                   The dude knows\n
# 1  The Big Lebowski                               The Dude Abides!!!\n
# 1  The Big Lebowski   Coen brothers unabashedly out of control! A p...
# 1  The Big Lebowski   A celebration of the ultimate man, nay, the u...
# 1  The Big Lebowski           That Rug Really Tied the Room Together\n
# 1  The Big Lebowski                               Respectable Raunch\n
# 1  The Big Lebowski   boe_dye sez: it wasn't funny, it wasn't not f...
# 1  The Big Lebowski          Biggest Movie Disappointment of My Life\n
# 1  The Big Lebowski                                     A Great film\n
# 1  The Big Lebowski                                 I do not get it.\n
# 1  The Big Lebowski                 What's the Point? It isn't funny\n
# 1  The Big Lebowski                             long, humorless film\n
# 1  The Big Lebowski                             and kept waiting....\n
# 1  The Big Lebowski                             I just don't get it.\n
# 1  The Big Lebowski   dear fans of "the big lebowski": what the hel...
# 1              /review/rw3000136/?ref_=tt_urv
# 1              /review/rw3004034/?ref_=tt_urv
# 1              /review/rw3789223/?ref_=tt_urv
# 1              /review/rw3164390/?ref_=tt_urv
# 1              /review/rw3736109/?ref_=tt_urv
# 1              /review/rw4168690/?ref_=tt_urv
# 1              /review/rw3838837/?ref_=tt_urv
# 1              /review/rw3126368/?ref_=tt_urv
# 1              /review/rw3001115/?ref_=tt_urv
# 1              /review/rw3000133/?ref_=tt_urv
# 1              /review/rw3846767/?ref_=tt_urv
# 1              /review/rw3028697/?ref_=tt_urv
# 1              /review/rw3000978/?ref_=tt_urv

# %%
# Importing NLTK library and all the books
import nltk
#nltk.download()
import os
#import readline
import numpy as np
import pandas as pd
#import nltk

from nltk.corpus import PlaintextCorpusReader
from nltk.tokenize import word_tokenize, sent_tokenize
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
#import tabulate
import urllib.request

import imdb
from bs4 import BeautifulSoup
import requests
import re
import json

my_movies = ["Shutter Island","split","Unbreakable"]
BASE_URL = "https://www.imdb.com"

# %%
tbl_imdb  = pd.DataFrame(columns = [
    'Movie_Name',
    'Review_Title',
    'Review_Desc',
    'Review_Rating',
    'Review_url'])

i_index=[]
i_index = 0

BASE_URL = "https://www.imdb.com/title/tt0088184/"

# %%
for movie_name in my_movies:
    
    ia = imdb.IMDb()
    
    results = ia.search_movie(movie_name)
    mv = results[0] 
    url = ia.get_imdbURL(mv)
    
    user_review_url = url + 'reviews/'
    response = requests.get(user_review_url)
    soup = BeautifulSoup(response.text, 'lxml')
    
    try:
        #print(soup)
        #movies = soup.select('a.title')
        #print("movies",movies)

        links = [a.attrs.get('href') for a in soup.select('a.title')]
        #print(links)

       # tbl_imdb = []

        # Store each item into dictionary (data), then put those into a list (imdb)
        
        for index in range(0, len(movies)):
            # Seperate movie into: 'place', 'title', 'year'
            
            review_title = movies[index].get_text()
            review_desc=""
            review_rating=""
            
            review_url = BASE_URL + links[index]
            
            r_response = requests.get(review_url)
            r_soup = BeautifulSoup(r_response.text, 'lxml')
#            print(r_soup)
            
            try:
                d1 = r_soup.find('script', type='application/ld+json')
                print(d1)
                d2 = d1.text
                data = json.loads(d2)
                
#                data = json.loads(r_soup.find('script', type='application/ld+json').text)

                review_desc = data['reviewBody']
                review_rating = data['reviewRating']['ratingValue']
            
                #best_rating = data['reviewRating']['bestRating']
                #worst_rating = data['reviewRating']['worstRating']
                
                print(review_desc)
                
            except Exception as e:
                print("Error review : " + str(e))
            
            raw_data = {'Movie_Name' : movie_name,
                    'Review_Title' : review_title,
                    'Review_Desc' : review_desc,
                    'Review_Rating' : review_rating,
                    'Review_url': links[index]}
            
            df_tbl = pd.DataFrame(raw_data,
                    columns = [
                        'Movie_Name',
                        'Review_Title',
                        'Review_Desc',
                        'Review_Rating',
                        'Review_url'], index = [i_index + 1])
            
            tbl_imdb = tbl_imdb.append(df_tbl)
            
    except Exception as e:
        print("Error :" + str(e))
# Out:
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# None
# Error review : 'NoneType' object has no attribute 'text'
# Error :HTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /title/tt0088184//review/rw4222656/?ref_=tt_urv (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
